# %%
import os
import logging
import json
import numpy as np
import pandas as pd
from datetime import datetime
from itertools import product
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from tqdm import tqdm
import sys

# 设置工作目录和路径
base_dir = "/Users/jessie/Documents/Projects/Cusanus_Topic_Modeling"
os.chdir(base_dir)

# 设置实验相关目录
dirs = {
    'input': 'experiments/lda/spacy/preprocessed',
    'output': 'experiments/lda/spacy/frequency_filtered',
    'logs': 'experiments/lda/spacy/frequency_filtered'
}

# 创建所需目录
for dir_path in dirs.values():
    os.makedirs(dir_path, exist_ok=True)

def load_paragraphs(input_dir: str) -> List[List[str]]:
    """
    加载所有文档的段落
    返回: 段落列表，每个段落是词列表
    """
    paragraphs = []
    
    # 遍历目录下的所有txt文件
    for filename in os.listdir(input_dir):
        if filename.endswith('.txt'):
            file_path = os.path.join(input_dir, filename)
            with open(file_path, 'r') as f:
                content = f.read()
                
            # 按段落分割
            para_texts = content.split('Paragraph')[1:]  # 跳过第一个空字符串
            
            for para in para_texts:
                # 提取段落编号和内容
                try:
                    para_num, para_content = para.split(':', 1)
                    # 分词并清理
                    words = para_content.strip().split()
                    if words:  # 只添加非空段落
                        paragraphs.append(words)
                except ValueError:
                    continue
                    
    logging.info(f"共加载 {len(paragraphs)} 个段落")
    return paragraphs

# %%
# 设置日志配置
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
log_file = os.path.join(dirs['logs'], f'threshold_evaluation_{timestamp}.log')

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)

# %%
def calculate_npmi(model: LdaModel, corpus_bow: List, dictionary: Dictionary, 
                  texts: List[List[str]], eps: float = 1e-12) -> float:
    """计算NPMI分数并标准化到[0,1]区间"""
    try:
        coherence_model = CoherenceModel(
            model=model, 
            texts=texts,
            dictionary=dictionary,
            coherence='c_npmi'
        )
        npmi = coherence_model.get_coherence()
        # 标准化到[0,1]区间
        npmi_norm = (npmi + 1) / 2
        return npmi_norm
    except Exception as e:
        logging.error(f"计算NPMI时发生错误: {str(e)}")
        return 0.0

def calculate_diversity(model: LdaModel, top_n: int = 10, eps: float = 1e-12) -> float:
    """计算主题多样性分数"""
    try:
        # 获取每个主题的前top_n个词
        topics = [dict(model.show_topic(i, top_n)) for i in range(model.num_topics)]
        unique_words = set()
        total_words = 0
        
        for topic in topics:
            unique_words.update(topic.keys())
            total_words += len(topic)
        
        # 确保结果在[0,1]区间
        diversity = min(1.0, max(0.0, len(unique_words) / (total_words + eps)))
        return diversity
    except Exception as e:
        logging.error(f"计算Diversity时发生错误: {str(e)}")
        return 0.0

# %%
def evaluate_thresholds(
    corpus: List[List[str]],
    min_freqs: List[int] = [2, 3, 4],
    max_freqs: List[int] = [200, 800, 1400, 2000],
    n_topics: int = 15,
    n_splits: int = 5,
    alpha: float = 0.5,
    random_state: int = 42
) -> Tuple[pd.DataFrame, Dict, List]:
    """评估不同词频阈值组合的效果"""
    
    # 初始化结果存储
    results = []
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    
    logging.info("开始阈值评估实验")
    logging.info(f"参数设置: n_topics={n_topics}, n_splits={n_splits}, alpha={alpha}")
    
    # 对所有参数组合进行网格搜索
    total_combinations = len(min_freqs) * len(max_freqs)
    
    with tqdm(total=total_combinations*n_splits, desc="实验进度") as pbar:
        for min_freq, max_freq in product(min_freqs, max_freqs):
            if min_freq >= max_freq:
                continue
                
            logging.info(f"\n评估阈值组合: min_freq={min_freq}, max_freq={max_freq}")
            fold_results = []
            
            # K折交叉验证
            for fold, (train_idx, val_idx) in enumerate(kf.split(corpus), 1):
                try:
                    # 构建词典
                    train_docs = [corpus[i] for i in train_idx]
                    dictionary = Dictionary(train_docs)
                    
                    # 应用词频过滤
                    original_tokens = len(dictionary)
                    dictionary.filter_extremes(
                        no_below=min_freq,
                        no_above=0.5,
                        keep_n=max_freq
                    )
                    filtered_tokens = len(dictionary)
                    
                    logging.info(f"词典过滤: {original_tokens} -> {filtered_tokens} 个词")
                    
                    # 转换为词袋表示
                    corpus_bow = [dictionary.doc2bow(doc) for doc in train_docs]
                    
                    # 训练LDA模型
                    lda = LdaModel(
                        corpus=corpus_bow,
                        id2word=dictionary,
                        num_topics=n_topics,
                        random_state=random_state
                    )
                    
                    # 计算评估指标
                    npmi_score = calculate_npmi(lda, corpus_bow, dictionary, train_docs)
                    diversity_score = calculate_diversity(lda)
                    
                    # 计算optimal score (已标准化的指标)
                    optimal_score = alpha * npmi_score + (1 - alpha) * diversity_score
                    
                    # 获取主题词
                    topics = lda.show_topics(formatted=False)
                    
                    fold_results.append({
                        'fold': fold,
                        'npmi': npmi_score,
                        'diversity': diversity_score,
                        'optimal_score': optimal_score,
                        'topics': topics
                    })
                    
                    logging.info(f"第 {fold} 折评估完成: "
                               f"NPMI={npmi_score:.4f}, "
                               f"Diversity={diversity_score:.4f}, "
                               f"Optimal Score={optimal_score:.4f}")
                    
                except Exception as e:
                    logging.error(f"处理第 {fold} 折时发生错误: {str(e)}")
                    continue
                finally:
                    pbar.update(1)
            
            # 计算平均分数
            if fold_results:
                avg_scores = {
                    'npmi': np.mean([r['npmi'] for r in fold_results]),
                    'diversity': np.mean([r['diversity'] for r in fold_results]),
                    'optimal_score': np.mean([r['optimal_score'] for r in fold_results])
                }
                
                std_scores = {
                    'npmi_std': np.std([r['npmi'] for r in fold_results]),
                    'diversity_std': np.std([r['diversity'] for r in fold_results]),
                    'optimal_score_std': np.std([r['optimal_score'] for r in fold_results])
                }
                
                results.append({
                    'min_freq': min_freq,
                    'max_freq': max_freq,
                    **avg_scores,
                    **std_scores,
                    'fold_results': fold_results
                })
    
    # 转换为DataFrame
    results_df = pd.DataFrame([
        {k: v for k, v in r.items() if k != 'fold_results'}
        for r in results
    ])
    
    # 找出最佳参数组合
    best_idx = results_df['optimal_score'].idxmax()
    best_params = {
        'min_freq': results_df.loc[best_idx, 'min_freq'],
        'max_freq': results_df.loc[best_idx, 'max_freq'],
        'optimal_score': results_df.loc[best_idx, 'optimal_score']
    }
    
    return results_df, best_params, results

# %%
def save_experiment_results(results_df: pd.DataFrame, best_params: Dict, raw_results: List, experiment_dir: str):
    """保存实验结果"""
    try:
        # 1. 保存DataFrame结果
        results_df.to_csv(os.path.join(experiment_dir, 'evaluation_results.csv'), index=False)
        logging.info("已保存评估结果DataFrame")
        
        # 2. 保存每折详细结果
        fold_results_df = pd.DataFrame([
            {
                'min_freq': result['min_freq'],
                'max_freq': result['max_freq'],
                'fold': fold_data['fold'],
                'npmi': fold_data['npmi'],
                'diversity': fold_data['diversity'],
                'optimal_score': fold_data['optimal_score']
            }
            for result in raw_results
            for fold_data in result['fold_results']
        ])
        fold_results_df.to_csv(os.path.join(experiment_dir, 'fold_results.csv'), index=False)
        logging.info("已保存每折详细结果")
        
        # 3. 保存主题词 - 添加类型转换
        topics_dir = os.path.join(experiment_dir, 'topics')
        os.makedirs(topics_dir, exist_ok=True)
        for result in raw_results:
            # 转换fold_results中的数据类型
            processed_fold_results = []
            for fold_data in result['fold_results']:
                processed_fold = {
                    'fold': int(fold_data['fold']),
                    'npmi': float(fold_data['npmi']),
                    'diversity': float(fold_data['diversity']),
                    'optimal_score': float(fold_data['optimal_score']),
                    'topics': [
                        [(str(word), float(score)) for word, score in topic]
                        for topic_id, topic in fold_data['topics']
                    ]
                }
                processed_fold_results.append(processed_fold)
                
            topics_file = os.path.join(
                topics_dir,
                f'topics_min{int(result["min_freq"])}_max{int(result["max_freq"])}.json'
            )
            with open(topics_file, 'w') as f:
                json.dump(processed_fold_results, f, indent=2)
        logging.info("已保存主题词结果")
        
        # 4. 保存最佳参数 - 添加类型转换
        processed_best_params = {
            'min_freq': int(best_params['min_freq']),
            'max_freq': int(best_params['max_freq']),
            'optimal_score': float(best_params['optimal_score'])
        }
        with open(os.path.join(experiment_dir, 'best_params.json'), 'w') as f:
            json.dump(processed_best_params, f, indent=2)
        logging.info("已保存最佳参数")
        
    except Exception as e:
        logging.error(f"保存结果时发生错误: {str(e)}")
        raise

# %%
def visualize_results(results_df: pd.DataFrame, experiment_dir: str):
    """生成可视化结果"""
    try:
        plt.figure(figsize=(12, 8))
        pivot_table = results_df.pivot(
            index='min_freq',
            columns='max_freq',
            values='optimal_score'
        )
        sns.heatmap(
            pivot_table,
            annot=True,
            fmt='.3f',
            cmap='YlOrRd',
            cbar_kws={'label': 'Optimal Score'}
        )
        plt.title('词频阈值组合评估结果')
        plt.xlabel('最大词频阈值')
        plt.ylabel('最小词频阈值')
        plt.tight_layout()
        plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
        plt.close()
        logging.info("已保存评估结果热力图")
    except Exception as e:
        logging.error(f"生成可视化结果时发生错误: {str(e)}")

# %%
# 主程序
if __name__ == "__main__":
    # 设置时间戳和实验目录
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    experiment_dir = os.path.join(dirs['output'], f'experiment_{timestamp}')
    os.makedirs(experiment_dir, exist_ok=True)

    # 设置日志
    log_file = os.path.join(dirs['logs'], f'threshold_evaluation_{timestamp}.log')
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler(log_file),
            logging.StreamHandler()
        ]
    )

    try:
        # 加载段落数据
        paragraphs = load_paragraphs(dirs['input'])
        logging.info(f"成功加载语料库，共 {len(paragraphs)} 个段落")

        # 运行实验
        results_df, best_params, raw_results = evaluate_thresholds(
            corpus=paragraphs,
            min_freqs=[2, 3, 4],
            max_freqs=[200, 800, 1400, 2000],
            n_topics=15,
            n_splits=5,
            alpha=0.5
        )

        # 保存结果
        save_experiment_results(results_df, best_params, raw_results, experiment_dir)
        print("实验结果已成功保存!")

        # 生成可视化
        visualize_results(results_df, experiment_dir)
        print("可视化结果已生成!")

        # 打印最佳参数
        print("\n最佳参数组合:")
        print(f"最小词频阈值: {best_params['min_freq']}")
        print(f"最大词频阈值: {best_params['max_freq']}")
        print(f"Optimal Score: {best_params['optimal_score']:.3f}")

    except Exception as e:
        logging.error(f"实验过程中发生错误: {str(e)}")
        raise
# Out:
# 2024-11-24 17:34:02,827 - INFO - 共加载 4515 个段落
# 2024-11-24 17:34:02,828 - INFO - 成功加载语料库，共 4515 个段落
# 2024-11-24 17:34:02,829 - INFO - 开始阈值评估实验
# 2024-11-24 17:34:02,829 - INFO - 参数设置: n_topics=15, n_splits=5, alpha=0.5
# 实验进度:   0%|          | 0/60 [00:00<?, ?it/s]2024-11-24 17:34:02,842 - INFO -
# 评估阈值组合: min_freq=2, max_freq=200
# 2024-11-24 17:34:02,848 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 17:34:02,936 - INFO - built Dictionary<10261 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 208518 corpus positions)
# 2024-11-24 17:34:02,937 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<10261 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 208518 corpus positions)", 'datetime': '2024-11-24T17:34:02.937457', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:02,943 - INFO - discarding 10061 tokens: [('aegeus', 2), ('andreo', 14), ('declaro', 39), ('deus', 2055), ('dominicus', 62), ('epistula', 73), ('folium', 12), ('historia', 46), ('hora', 56), ('lombardicus', 3)]...
# 2024-11-24 17:34:02,944 - INFO - keeping 200 tokens which were in no less than 2 and no more than 1806 (=50.0%) documents
# 2024-11-24 17:34:02,945 - INFO - resulting dictionary: Dictionary<200 unique tokens: ['ada', 'apostolus', 'christus', 'considero', 'dominus']...>
# 2024-11-24 17:34:02,945 - INFO - 词典过滤: 10261 -> 200 个词
# 2024-11-24 17:34:02,984 - INFO - using symmetric alpha at 0.06666666666666667
# 2024-11-24 17:34:02,985 - INFO - using symmetric eta at 0.06666666666666667
# 2024-11-24 17:34:02,985 - INFO - using serial LDA version on this node
# 2024-11-24 17:34:02,987 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 17:34:02,987 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 17:34:02,988 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 17:34:03,342 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 17:34:03,343 - INFO - topic #13 (0.067): 0.073*"uita" + 0.037*"nomen" + 0.026*"christus" + 0.025*"dominus" + 0.024*"quaero" + 0.021*"gaudium" + 0.018*"homo" + 0.018*"spiritus" + 0.015*"ueritas" + 0.014*"caelum"
# 2024-11-24 17:34:03,344 - INFO - topic #8 (0.067): 0.079*"christus" + 0.021*"corpus" + 0.021*"spiritus" + 0.019*"uerbum" + 0.018*"homo" + 0.017*"dies" + 0.016*"uita" + 0.016*"anima" + 0.016*"amor" + 0.015*"uirtus"
# 2024-11-24 17:34:03,344 - INFO - topic #14 (0.067): 0.057*"spiritus" + 0.050*"fides" + 0.039*"pater" + 0.031*"christus" + 0.030*"homo" + 0.028*"filius" + 0.027*"uerbum" + 0.017*"nomen" + 0.015*"uita" + 0.015*"dies"
# 2024-11-24 17:34:03,345 - INFO - topic #7 (0.067): 0.042*"intellectus" + 0.035*"spiritus" + 0.030*"uerbum" + 0.029*"lumen" + 0.027*"lux" + 0.024*"uita" + 0.023*"intellego" + 0.019*"pater" + 0.019*"uiuo" + 0.018*"anima"
# 2024-11-24 17:34:03,345 - INFO - topic #9 (0.067): 0.054*"mundus" + 0.036*"uita" + 0.034*"christus" + 0.028*"natura" + 0.026*"ueritas" + 0.019*"fides" + 0.018*"homo" + 0.018*"intellectualis" + 0.014*"sensibilis" + 0.014*"caelum"
# 2024-11-24 17:34:03,345 - INFO - topic diff=0.765769, rho=1.000000
# 2024-11-24 17:34:03,696 - INFO - -5.193 per-word bound, 36.6 perplexity estimate based on a held-out corpus of 1612 documents with 42258 words
# 2024-11-24 17:34:03,697 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 17:34:03,980 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 17:34:03,981 - INFO - topic #5 (0.067): 0.053*"spiritus" + 0.037*"filius" + 0.032*"uerbum" + 0.026*"regnum" + 0.021*"mare" + 0.020*"uenio" + 0.019*"desiderium" + 0.019*"euangelium" + 0.018*"sermo" + 0.017*"homo"
# 2024-11-24 17:34:03,981 - INFO - topic #13 (0.067): 0.085*"uita" + 0.082*"nomen" + 0.030*"gaudium" + 0.028*"quaero" + 0.028*"dominus" + 0.023*"christus" + 0.019*"reperio" + 0.016*"spiritus" + 0.015*"uiuo" + 0.015*"caelum"
# 2024-11-24 17:34:03,982 - INFO - topic #2 (0.067): 0.046*"spiritus" + 0.039*"pater" + 0.033*"iustitia" + 0.029*"christus" + 0.026*"sanctus" + 0.024*"misericordia" + 0.023*"filius" + 0.020*"lex" + 0.018*"semen" + 0.018*"uita"
# 2024-11-24 17:34:03,982 - INFO - topic #1 (0.067): 0.071*"homo" + 0.056*"uita" + 0.039*"mors" + 0.034*"christus" + 0.027*"iustitia" + 0.023*"sapientia" + 0.019*"gratia" + 0.019*"spiritus" + 0.016*"magnus" + 0.015*"anima"
# 2024-11-24 17:34:03,983 - INFO - topic #11 (0.067): 0.075*"uerbum" + 0.061*"christus" + 0.026*"filius" + 0.023*"uita" + 0.020*"uia" + 0.020*"pater" + 0.019*"homo" + 0.017*"ostendo" + 0.016*"nosco" + 0.016*"audio"
# 2024-11-24 17:34:03,983 - INFO - topic diff=0.355951, rho=0.707107
# 2024-11-24 17:34:03,983 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=200, num_topics=15, decay=0.5, chunksize=2000> in 1.00s', 'datetime': '2024-11-24T17:34:03.983850', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:03,986 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 17:34:04,041 - INFO - 1 batches submitted to accumulate stats from 64 documents (4269 virtual)
# 2024-11-24 17:34:04,051 - INFO - 2 batches submitted to accumulate stats from 128 documents (7939 virtual)
# 2024-11-24 17:34:04,057 - INFO - 3 batches submitted to accumulate stats from 192 documents (11439 virtual)
# 2024-11-24 17:34:04,060 - INFO - 4 batches submitted to accumulate stats from 256 documents (15651 virtual)
# 2024-11-24 17:34:04,064 - INFO - 5 batches submitted to accumulate stats from 320 documents (19821 virtual)
# 2024-11-24 17:34:04,066 - INFO - 6 batches submitted to accumulate stats from 384 documents (23580 virtual)
# 2024-11-24 17:34:04,071 - INFO - 7 batches submitted to accumulate stats from 448 documents (27987 virtual)
# 2024-11-24 17:34:04,998 - INFO - 8 batches submitted to accumulate stats from 512 documents (33050 virtual)
# 2024-11-24 17:34:05,044 - INFO - 9 batches submitted to accumulate stats from 576 documents (37533 virtual)
# 2024-11-24 17:34:05,077 - INFO - 10 batches submitted to accumulate stats from 640 documents (40907 virtual)
# 2024-11-24 17:34:05,115 - INFO - 11 batches submitted to accumulate stats from 704 documents (44987 virtual)
# 2024-11-24 17:34:05,123 - INFO - 12 batches submitted to accumulate stats from 768 documents (49052 virtual)
# 2024-11-24 17:34:05,126 - INFO - 13 batches submitted to accumulate stats from 832 documents (52492 virtual)
# 2024-11-24 17:34:05,129 - INFO - 14 batches submitted to accumulate stats from 896 documents (55409 virtual)
# 2024-11-24 17:34:05,131 - INFO - 15 batches submitted to accumulate stats from 960 documents (57711 virtual)
# 2024-11-24 17:34:05,137 - INFO - 16 batches submitted to accumulate stats from 1024 documents (59677 virtual)
# 2024-11-24 17:34:05,139 - INFO - 17 batches submitted to accumulate stats from 1088 documents (61925 virtual)
# 2024-11-24 17:34:05,153 - INFO - 18 batches submitted to accumulate stats from 1152 documents (64570 virtual)
# 2024-11-24 17:34:05,155 - INFO - 19 batches submitted to accumulate stats from 1216 documents (67367 virtual)
# 2024-11-24 17:34:05,160 - INFO - 20 batches submitted to accumulate stats from 1280 documents (69782 virtual)
# 2024-11-24 17:34:05,165 - INFO - 21 batches submitted to accumulate stats from 1344 documents (72053 virtual)
# 2024-11-24 17:34:05,180 - INFO - 22 batches submitted to accumulate stats from 1408 documents (74821 virtual)
# 2024-11-24 17:34:05,199 - INFO - 23 batches submitted to accumulate stats from 1472 documents (77187 virtual)
# 2024-11-24 17:34:05,205 - INFO - 24 batches submitted to accumulate stats from 1536 documents (79500 virtual)
# 2024-11-24 17:34:05,207 - INFO - 25 batches submitted to accumulate stats from 1600 documents (83183 virtual)
# 2024-11-24 17:34:05,211 - INFO - 26 batches submitted to accumulate stats from 1664 documents (85412 virtual)
# 2024-11-24 17:34:05,216 - INFO - 27 batches submitted to accumulate stats from 1728 documents (87988 virtual)
# 2024-11-24 17:34:05,220 - INFO - 28 batches submitted to accumulate stats from 1792 documents (90193 virtual)
# 2024-11-24 17:34:05,221 - INFO - 29 batches submitted to accumulate stats from 1856 documents (92476 virtual)
# 2024-11-24 17:34:05,222 - INFO - 30 batches submitted to accumulate stats from 1920 documents (95279 virtual)
# 2024-11-24 17:34:05,224 - INFO - 31 batches submitted to accumulate stats from 1984 documents (97060 virtual)
# 2024-11-24 17:34:05,230 - INFO - 32 batches submitted to accumulate stats from 2048 documents (99562 virtual)
# 2024-11-24 17:34:05,232 - INFO - 33 batches submitted to accumulate stats from 2112 documents (101877 virtual)
# 2024-11-24 17:34:05,235 - INFO - 34 batches submitted to accumulate stats from 2176 documents (104929 virtual)
# 2024-11-24 17:34:05,238 - INFO - 35 batches submitted to accumulate stats from 2240 documents (108587 virtual)
# 2024-11-24 17:34:05,240 - INFO - 36 batches submitted to accumulate stats from 2304 documents (110954 virtual)
# 2024-11-24 17:34:05,246 - INFO - 37 batches submitted to accumulate stats from 2368 documents (112789 virtual)
# 2024-11-24 17:34:05,247 - INFO - 38 batches submitted to accumulate stats from 2432 documents (115979 virtual)
# 2024-11-24 17:34:05,250 - INFO - 39 batches submitted to accumulate stats from 2496 documents (118495 virtual)
# 2024-11-24 17:34:05,253 - INFO - 40 batches submitted to accumulate stats from 2560 documents (120818 virtual)
# 2024-11-24 17:34:05,256 - INFO - 41 batches submitted to accumulate stats from 2624 documents (123331 virtual)
# 2024-11-24 17:34:05,258 - INFO - 42 batches submitted to accumulate stats from 2688 documents (125882 virtual)
# 2024-11-24 17:34:05,263 - INFO - 43 batches submitted to accumulate stats from 2752 documents (128536 virtual)
# 2024-11-24 17:34:05,264 - INFO - 44 batches submitted to accumulate stats from 2816 documents (130584 virtual)
# 2024-11-24 17:34:05,266 - INFO - 45 batches submitted to accumulate stats from 2880 documents (133165 virtual)
# 2024-11-24 17:34:05,270 - INFO - 46 batches submitted to accumulate stats from 2944 documents (136131 virtual)
# 2024-11-24 17:34:05,272 - INFO - 47 batches submitted to accumulate stats from 3008 documents (140060 virtual)
# 2024-11-24 17:34:05,274 - INFO - 48 batches submitted to accumulate stats from 3072 documents (143128 virtual)
# 2024-11-24 17:34:05,278 - INFO - 49 batches submitted to accumulate stats from 3136 documents (147970 virtual)
# 2024-11-24 17:34:05,285 - INFO - 50 batches submitted to accumulate stats from 3200 documents (152025 virtual)
# 2024-11-24 17:34:05,287 - INFO - 51 batches submitted to accumulate stats from 3264 documents (156262 virtual)
# 2024-11-24 17:34:05,289 - INFO - 52 batches submitted to accumulate stats from 3328 documents (160548 virtual)
# 2024-11-24 17:34:05,294 - INFO - 53 batches submitted to accumulate stats from 3392 documents (164314 virtual)
# 2024-11-24 17:34:05,297 - INFO - 54 batches submitted to accumulate stats from 3456 documents (168464 virtual)
# 2024-11-24 17:34:05,300 - INFO - 55 batches submitted to accumulate stats from 3520 documents (171500 virtual)
# 2024-11-24 17:34:05,302 - INFO - 56 batches submitted to accumulate stats from 3584 documents (174685 virtual)
# 2024-11-24 17:34:05,305 - INFO - 57 batches submitted to accumulate stats from 3648 documents (176010 virtual)
# 2024-11-24 17:34:05,376 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 17:34:05,388 - INFO - accumulated word occurrence stats for 176247 virtual documents
# 2024-11-24 17:34:05,562 - INFO - 第 1 折评估完成: NPMI=0.4973, Diversity=0.4533, Optimal Score=0.4753
# 实验进度:   2%|▏         | 1/60 [00:02<02:40,  2.72s/it]2024-11-24 17:34:05,564 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 17:34:05,648 - INFO - built Dictionary<10340 unique tokens: ['apostolus', 'attendo', 'completio', 'complico', 'credo']...> from 3612 documents (total 209763 corpus positions)
# 2024-11-24 17:34:05,649 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<10340 unique tokens: ['apostolus', 'attendo', 'completio', 'complico', 'credo']...> from 3612 documents (total 209763 corpus positions)", 'datetime': '2024-11-24T17:34:05.648987', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:05,653 - INFO - discarding 10140 tokens: [('completio', 11), ('dilectio', 118), ('hora', 53), ('plenitudo', 112), ('praeceptum', 83), ('probo', 69), ('propior', 2), ('proximus', 95), ('somnus', 9), ('subiungo', 73)]...
# 2024-11-24 17:34:05,654 - INFO - keeping 200 tokens which were in no less than 2 and no more than 1806 (=50.0%) documents
# 2024-11-24 17:34:05,655 - INFO - resulting dictionary: Dictionary<200 unique tokens: ['apostolus', 'attendo', 'complico', 'credo', 'lex']...>
# 2024-11-24 17:34:05,655 - INFO - 词典过滤: 10340 -> 200 个词
# 2024-11-24 17:34:05,740 - INFO - using symmetric alpha at 0.06666666666666667
# 2024-11-24 17:34:05,741 - INFO - using symmetric eta at 0.06666666666666667
# 2024-11-24 17:34:05,742 - INFO - using serial LDA version on this node
# 2024-11-24 17:34:05,742 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 17:34:05,742 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 17:34:05,743 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 17:34:06,055 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 17:34:06,056 - INFO - topic #13 (0.067): 0.038*"spiritus" + 0.031*"uerbum" + 0.031*"homo" + 0.030*"iustitia" + 0.028*"semen" + 0.021*"anima" + 0.021*"uita" + 0.019*"mundus" + 0.017*"uenio" + 0.017*"christus"
# 2024-11-24 17:34:06,056 - INFO - topic #8 (0.067): 0.058*"pater" + 0.050*"uerbum" + 0.038*"audio" + 0.026*"lux" + 0.026*"mundus" + 0.020*"ratio" + 0.019*"nomen" + 0.017*"aeternus" + 0.017*"ars" + 0.017*"lumen"
# 2024-11-24 17:34:06,056 - INFO - topic #14 (0.067): 0.066*"christus" + 0.031*"uita" + 0.026*"lux" + 0.024*"homo" + 0.021*"uerbum" + 0.019*"uirtus" + 0.018*"filius" + 0.018*"corpus" + 0.015*"uiuo" + 0.014*"peccatum"
# 2024-11-24 17:34:06,057 - INFO - topic #7 (0.067): 0.049*"christus" + 0.035*"ueritas" + 0.027*"uerbum" + 0.026*"uita" + 0.024*"filius" + 0.024*"spiritus" + 0.023*"pater" + 0.022*"caritas" + 0.021*"homo" + 0.021*"anima"
# 2024-11-24 17:34:06,057 - INFO - topic #9 (0.067): 0.054*"spiritus" + 0.038*"christus" + 0.029*"debeo" + 0.029*"fides" + 0.023*"homo" + 0.022*"mundus" + 0.017*"amor" + 0.016*"amo" + 0.016*"dies" + 0.016*"mors"
# 2024-11-24 17:34:06,057 - INFO - topic diff=0.788301, rho=1.000000
# 2024-11-24 17:34:06,342 - INFO - -5.187 per-word bound, 36.4 perplexity estimate based on a held-out corpus of 1612 documents with 42738 words
# 2024-11-24 17:34:06,342 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 17:34:06,581 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 17:34:06,582 - INFO - topic #5 (0.067): 0.123*"spiritus" + 0.058*"christus" + 0.034*"sanctus" + 0.032*"aqua" + 0.021*"uita" + 0.019*"homo" + 0.017*"natura" + 0.016*"uenio" + 0.016*"uirtus" + 0.015*"scio"
# 2024-11-24 17:34:06,583 - INFO - topic #13 (0.067): 0.051*"iustitia" + 0.041*"spiritus" + 0.033*"homo" + 0.028*"semen" + 0.027*"anima" + 0.024*"uerbum" + 0.022*"moueo" + 0.022*"mundus" + 0.021*"uita" + 0.020*"uenio"
# 2024-11-24 17:34:06,583 - INFO - topic #2 (0.067): 0.070*"spiritus" + 0.041*"dies" + 0.030*"motus" + 0.029*"uirtus" + 0.021*"regnum" + 0.021*"mundus" + 0.021*"locus" + 0.019*"fides" + 0.019*"homo" + 0.016*"angelus"
# 2024-11-24 17:34:06,583 - INFO - topic #1 (0.067): 0.130*"uita" + 0.057*"amor" + 0.042*"spiritus" + 0.028*"diligo" + 0.026*"anima" + 0.022*"caritas" + 0.019*"christus" + 0.019*"amo" + 0.017*"uiuo" + 0.017*"ignis"
# 2024-11-24 17:34:06,584 - INFO - topic #11 (0.067): 0.056*"homo" + 0.037*"christus" + 0.032*"uita" + 0.031*"mors" + 0.028*"caelum" + 0.024*"intro" + 0.020*"anima" + 0.017*"uolo" + 0.017*"sanctus" + 0.017*"mundus"
# 2024-11-24 17:34:06,584 - INFO - topic diff=0.364903, rho=0.707107
# 2024-11-24 17:34:06,584 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=200, num_topics=15, decay=0.5, chunksize=2000> in 0.84s', 'datetime': '2024-11-24T17:34:06.584861', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:06,587 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 17:34:06,630 - INFO - 1 batches submitted to accumulate stats from 64 documents (4323 virtual)
# 2024-11-24 17:34:06,633 - INFO - 2 batches submitted to accumulate stats from 128 documents (8129 virtual)
# 2024-11-24 17:34:06,637 - INFO - 3 batches submitted to accumulate stats from 192 documents (11823 virtual)
# 2024-11-24 17:34:06,639 - INFO - 4 batches submitted to accumulate stats from 256 documents (15714 virtual)
# 2024-11-24 17:34:06,640 - INFO - 5 batches submitted to accumulate stats from 320 documents (20104 virtual)
# 2024-11-24 17:34:06,644 - INFO - 6 batches submitted to accumulate stats from 384 documents (23873 virtual)
# 2024-11-24 17:34:06,648 - INFO - 7 batches submitted to accumulate stats from 448 documents (27706 virtual)
# 2024-11-24 17:34:07,489 - INFO - 8 batches submitted to accumulate stats from 512 documents (32283 virtual)
# 2024-11-24 17:34:07,541 - INFO - 9 batches submitted to accumulate stats from 576 documents (37290 virtual)
# 2024-11-24 17:34:07,564 - INFO - 10 batches submitted to accumulate stats from 640 documents (40297 virtual)
# 2024-11-24 17:34:07,574 - INFO - 11 batches submitted to accumulate stats from 704 documents (45527 virtual)
# 2024-11-24 17:34:07,583 - INFO - 12 batches submitted to accumulate stats from 768 documents (49625 virtual)
# 2024-11-24 17:34:07,586 - INFO - 13 batches submitted to accumulate stats from 832 documents (53098 virtual)
# 2024-11-24 17:34:07,594 - INFO - 14 batches submitted to accumulate stats from 896 documents (55724 virtual)
# 2024-11-24 17:34:07,596 - INFO - 15 batches submitted to accumulate stats from 960 documents (58500 virtual)
# 2024-11-24 17:34:07,620 - INFO - 16 batches submitted to accumulate stats from 1024 documents (60172 virtual)
# 2024-11-24 17:34:07,624 - INFO - 17 batches submitted to accumulate stats from 1088 documents (62376 virtual)
# 2024-11-24 17:34:07,630 - INFO - 18 batches submitted to accumulate stats from 1152 documents (64994 virtual)
# 2024-11-24 17:34:07,632 - INFO - 19 batches submitted to accumulate stats from 1216 documents (67739 virtual)
# 2024-11-24 17:34:07,635 - INFO - 20 batches submitted to accumulate stats from 1280 documents (70269 virtual)
# 2024-11-24 17:34:07,637 - INFO - 21 batches submitted to accumulate stats from 1344 documents (72239 virtual)
# 2024-11-24 17:34:07,650 - INFO - 22 batches submitted to accumulate stats from 1408 documents (74381 virtual)
# 2024-11-24 17:34:07,660 - INFO - 23 batches submitted to accumulate stats from 1472 documents (77256 virtual)
# 2024-11-24 17:34:07,662 - INFO - 24 batches submitted to accumulate stats from 1536 documents (79125 virtual)
# 2024-11-24 17:34:07,665 - INFO - 25 batches submitted to accumulate stats from 1600 documents (82261 virtual)
# 2024-11-24 17:34:07,669 - INFO - 26 batches submitted to accumulate stats from 1664 documents (84986 virtual)
# 2024-11-24 17:34:07,674 - INFO - 27 batches submitted to accumulate stats from 1728 documents (87617 virtual)
# 2024-11-24 17:34:07,678 - INFO - 28 batches submitted to accumulate stats from 1792 documents (89776 virtual)
# 2024-11-24 17:34:07,682 - INFO - 29 batches submitted to accumulate stats from 1856 documents (92145 virtual)
# 2024-11-24 17:34:07,684 - INFO - 30 batches submitted to accumulate stats from 1920 documents (95022 virtual)
# 2024-11-24 17:34:07,687 - INFO - 31 batches submitted to accumulate stats from 1984 documents (96945 virtual)
# 2024-11-24 17:34:07,688 - INFO - 32 batches submitted to accumulate stats from 2048 documents (99167 virtual)
# 2024-11-24 17:34:07,690 - INFO - 33 batches submitted to accumulate stats from 2112 documents (101449 virtual)
# 2024-11-24 17:34:07,694 - INFO - 34 batches submitted to accumulate stats from 2176 documents (104705 virtual)
# 2024-11-24 17:34:07,698 - INFO - 35 batches submitted to accumulate stats from 2240 documents (108244 virtual)
# 2024-11-24 17:34:07,704 - INFO - 36 batches submitted to accumulate stats from 2304 documents (110643 virtual)
# 2024-11-24 17:34:07,708 - INFO - 37 batches submitted to accumulate stats from 2368 documents (112572 virtual)
# 2024-11-24 17:34:07,713 - INFO - 38 batches submitted to accumulate stats from 2432 documents (115668 virtual)
# 2024-11-24 17:34:07,714 - INFO - 39 batches submitted to accumulate stats from 2496 documents (118114 virtual)
# 2024-11-24 17:34:07,716 - INFO - 40 batches submitted to accumulate stats from 2560 documents (120394 virtual)
# 2024-11-24 17:34:07,717 - INFO - 41 batches submitted to accumulate stats from 2624 documents (122916 virtual)
# 2024-11-24 17:34:07,720 - INFO - 42 batches submitted to accumulate stats from 2688 documents (125395 virtual)
# 2024-11-24 17:34:07,727 - INFO - 43 batches submitted to accumulate stats from 2752 documents (128202 virtual)
# 2024-11-24 17:34:07,735 - INFO - 44 batches submitted to accumulate stats from 2816 documents (130298 virtual)
# 2024-11-24 17:34:07,738 - INFO - 45 batches submitted to accumulate stats from 2880 documents (132963 virtual)
# 2024-11-24 17:34:07,740 - INFO - 46 batches submitted to accumulate stats from 2944 documents (135830 virtual)
# 2024-11-24 17:34:07,745 - INFO - 47 batches submitted to accumulate stats from 3008 documents (140270 virtual)
# 2024-11-24 17:34:07,747 - INFO - 48 batches submitted to accumulate stats from 3072 documents (143190 virtual)
# 2024-11-24 17:34:07,749 - INFO - 49 batches submitted to accumulate stats from 3136 documents (147697 virtual)
# 2024-11-24 17:34:07,754 - INFO - 50 batches submitted to accumulate stats from 3200 documents (151964 virtual)
# 2024-11-24 17:34:07,756 - INFO - 51 batches submitted to accumulate stats from 3264 documents (156493 virtual)
# 2024-11-24 17:34:07,763 - INFO - 52 batches submitted to accumulate stats from 3328 documents (160615 virtual)
# 2024-11-24 17:34:07,765 - INFO - 53 batches submitted to accumulate stats from 3392 documents (164919 virtual)
# 2024-11-24 17:34:07,767 - INFO - 54 batches submitted to accumulate stats from 3456 documents (169024 virtual)
# 2024-11-24 17:34:07,769 - INFO - 55 batches submitted to accumulate stats from 3520 documents (172176 virtual)
# 2024-11-24 17:34:07,777 - INFO - 56 batches submitted to accumulate stats from 3584 documents (175665 virtual)
# 2024-11-24 17:34:07,784 - INFO - 57 batches submitted to accumulate stats from 3648 documents (177255 virtual)
# 2024-11-24 17:34:07,907 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 17:34:07,924 - INFO - accumulated word occurrence stats for 177437 virtual documents
# 2024-11-24 17:34:08,078 - INFO - 第 2 折评估完成: NPMI=0.4971, Diversity=0.4400, Optimal Score=0.4686
# 实验进度:   3%|▎         | 2/60 [00:05<02:30,  2.60s/it]2024-11-24 17:34:08,080 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 17:34:08,157 - INFO - built Dictionary<10331 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 209219 corpus positions)
# 2024-11-24 17:34:08,158 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<10331 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 209219 corpus positions)", 'datetime': '2024-11-24T17:34:08.158336', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:08,162 - INFO - discarding 10131 tokens: [('aegeus', 2), ('andreo', 11), ('declaro', 44), ('deus', 2065), ('dominicus', 59), ('epistula', 68), ('folium', 15), ('historia', 52), ('hora', 58), ('lombardicus', 3)]...
# 2024-11-24 17:34:08,162 - INFO - keeping 200 tokens which were in no less than 2 and no more than 1806 (=50.0%) documents
# 2024-11-24 17:34:08,163 - INFO - resulting dictionary: Dictionary<200 unique tokens: ['ada', 'apostolus', 'christus', 'considero', 'dominus']...>
# 2024-11-24 17:34:08,164 - INFO - 词典过滤: 10331 -> 200 个词
# 2024-11-24 17:34:08,200 - INFO - using symmetric alpha at 0.06666666666666667
# 2024-11-24 17:34:08,201 - INFO - using symmetric eta at 0.06666666666666667
# 2024-11-24 17:34:08,201 - INFO - using serial LDA version on this node
# 2024-11-24 17:34:08,202 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 17:34:08,202 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 17:34:08,202 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 17:34:08,589 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 17:34:08,590 - INFO - topic #13 (0.067): 0.047*"uerbum" + 0.034*"pater" + 0.032*"nomen" + 0.030*"christus" + 0.028*"uita" + 0.021*"amo" + 0.019*"filius" + 0.016*"amor" + 0.016*"cognosco" + 0.015*"homo"
# 2024-11-24 17:34:08,590 - INFO - topic #8 (0.067): 0.085*"christus" + 0.055*"spiritus" + 0.024*"homo" + 0.024*"anima" + 0.020*"gratia" + 0.018*"natura" + 0.018*"mundus" + 0.018*"moueo" + 0.016*"unio" + 0.013*"recipio"
# 2024-11-24 17:34:08,591 - INFO - topic #14 (0.067): 0.046*"christus" + 0.038*"mors" + 0.026*"uerbum" + 0.025*"uita" + 0.024*"homo" + 0.018*"lux" + 0.017*"intellego" + 0.016*"uenio" + 0.016*"filius" + 0.016*"anima"
# 2024-11-24 17:34:08,591 - INFO - topic #7 (0.067): 0.035*"uerbum" + 0.027*"dominus" + 0.023*"anima" + 0.022*"christus" + 0.019*"pater" + 0.019*"uita" + 0.018*"audio" + 0.018*"filius" + 0.017*"uirtus" + 0.017*"natura"
# 2024-11-24 17:34:08,591 - INFO - topic #9 (0.067): 0.035*"homo" + 0.033*"christus" + 0.024*"sanctus" + 0.019*"ratio" + 0.018*"bonum" + 0.017*"mors" + 0.016*"spiritus" + 0.016*"caelum" + 0.015*"pater" + 0.014*"mitto"
# 2024-11-24 17:34:08,592 - INFO - topic diff=0.736406, rho=1.000000
# 2024-11-24 17:34:08,901 - INFO - -5.188 per-word bound, 36.5 perplexity estimate based on a held-out corpus of 1612 documents with 42410 words
# 2024-11-24 17:34:08,902 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 17:34:09,129 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 17:34:09,130 - INFO - topic #5 (0.067): 0.088*"filius" + 0.047*"homo" + 0.040*"pater" + 0.025*"uerbum" + 0.025*"sapientia" + 0.024*"spiritus" + 0.021*"fides" + 0.020*"nascor" + 0.019*"creatura" + 0.019*"mundus"
# 2024-11-24 17:34:09,130 - INFO - topic #13 (0.067): 0.070*"nomen" + 0.048*"uerbum" + 0.042*"pater" + 0.032*"rex" + 0.029*"christus" + 0.024*"uita" + 0.020*"filius" + 0.020*"quaero" + 0.016*"iustitia" + 0.016*"amo"
# 2024-11-24 17:34:09,131 - INFO - topic #2 (0.067): 0.057*"mundus" + 0.052*"uita" + 0.033*"christus" + 0.028*"fides" + 0.025*"homo" + 0.024*"sapientia" + 0.022*"uenio" + 0.019*"spiritus" + 0.018*"anima" + 0.018*"sensibilis"
# 2024-11-24 17:34:09,131 - INFO - topic #1 (0.067): 0.050*"homo" + 0.038*"iustitia" + 0.031*"anima" + 0.030*"locus" + 0.030*"debeo" + 0.028*"uita" + 0.026*"ignis" + 0.026*"uirtus" + 0.019*"christus" + 0.018*"mens"
# 2024-11-24 17:34:09,131 - INFO - topic #11 (0.067): 0.076*"christus" + 0.062*"uita" + 0.054*"fides" + 0.029*"spiritus" + 0.028*"anima" + 0.025*"uerbum" + 0.023*"corpus" + 0.022*"uirtus" + 0.021*"filius" + 0.018*"iesus"
# 2024-11-24 17:34:09,132 - INFO - topic diff=0.333358, rho=0.707107
# 2024-11-24 17:34:09,132 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=200, num_topics=15, decay=0.5, chunksize=2000> in 0.93s', 'datetime': '2024-11-24T17:34:09.132289', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:09,134 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 17:34:09,185 - INFO - 1 batches submitted to accumulate stats from 64 documents (4375 virtual)
# 2024-11-24 17:34:09,192 - INFO - 2 batches submitted to accumulate stats from 128 documents (7823 virtual)
# 2024-11-24 17:34:09,433 - INFO - 3 batches submitted to accumulate stats from 192 documents (11688 virtual)
# 2024-11-24 17:34:09,435 - INFO - 4 batches submitted to accumulate stats from 256 documents (15879 virtual)
# 2024-11-24 17:34:09,437 - INFO - 5 batches submitted to accumulate stats from 320 documents (20004 virtual)
# 2024-11-24 17:34:09,438 - INFO - 6 batches submitted to accumulate stats from 384 documents (23681 virtual)
# 2024-11-24 17:34:09,439 - INFO - 7 batches submitted to accumulate stats from 448 documents (27831 virtual)
# 2024-11-24 17:34:10,079 - INFO - 8 batches submitted to accumulate stats from 512 documents (32346 virtual)
# 2024-11-24 17:34:10,103 - INFO - 9 batches submitted to accumulate stats from 576 documents (37218 virtual)
# 2024-11-24 17:34:10,114 - INFO - 10 batches submitted to accumulate stats from 640 documents (40211 virtual)
# 2024-11-24 17:34:10,117 - INFO - 11 batches submitted to accumulate stats from 704 documents (45360 virtual)
# 2024-11-24 17:34:10,119 - INFO - 12 batches submitted to accumulate stats from 768 documents (49489 virtual)
# 2024-11-24 17:34:10,122 - INFO - 13 batches submitted to accumulate stats from 832 documents (53129 virtual)
# 2024-11-24 17:34:10,124 - INFO - 14 batches submitted to accumulate stats from 896 documents (55630 virtual)
# 2024-11-24 17:34:10,132 - INFO - 15 batches submitted to accumulate stats from 960 documents (58663 virtual)
# 2024-11-24 17:34:10,140 - INFO - 16 batches submitted to accumulate stats from 1024 documents (60463 virtual)
# 2024-11-24 17:34:10,147 - INFO - 17 batches submitted to accumulate stats from 1088 documents (62564 virtual)
# 2024-11-24 17:34:10,153 - INFO - 18 batches submitted to accumulate stats from 1152 documents (65250 virtual)
# 2024-11-24 17:34:10,154 - INFO - 19 batches submitted to accumulate stats from 1216 documents (67766 virtual)
# 2024-11-24 17:34:10,159 - INFO - 20 batches submitted to accumulate stats from 1280 documents (70381 virtual)
# 2024-11-24 17:34:10,162 - INFO - 21 batches submitted to accumulate stats from 1344 documents (72382 virtual)
# 2024-11-24 17:34:10,168 - INFO - 22 batches submitted to accumulate stats from 1408 documents (74620 virtual)
# 2024-11-24 17:34:10,171 - INFO - 23 batches submitted to accumulate stats from 1472 documents (77516 virtual)
# 2024-11-24 17:34:10,177 - INFO - 24 batches submitted to accumulate stats from 1536 documents (79498 virtual)
# 2024-11-24 17:34:10,182 - INFO - 25 batches submitted to accumulate stats from 1600 documents (83001 virtual)
# 2024-11-24 17:34:10,186 - INFO - 26 batches submitted to accumulate stats from 1664 documents (85772 virtual)
# 2024-11-24 17:34:10,188 - INFO - 27 batches submitted to accumulate stats from 1728 documents (87857 virtual)
# 2024-11-24 17:34:10,196 - INFO - 28 batches submitted to accumulate stats from 1792 documents (90377 virtual)
# 2024-11-24 17:34:10,198 - INFO - 29 batches submitted to accumulate stats from 1856 documents (92477 virtual)
# 2024-11-24 17:34:10,199 - INFO - 30 batches submitted to accumulate stats from 1920 documents (94864 virtual)
# 2024-11-24 17:34:10,203 - INFO - 31 batches submitted to accumulate stats from 1984 documents (96925 virtual)
# 2024-11-24 17:34:10,205 - INFO - 32 batches submitted to accumulate stats from 2048 documents (99587 virtual)
# 2024-11-24 17:34:10,207 - INFO - 33 batches submitted to accumulate stats from 2112 documents (101738 virtual)
# 2024-11-24 17:34:10,209 - INFO - 34 batches submitted to accumulate stats from 2176 documents (104746 virtual)
# 2024-11-24 17:34:10,215 - INFO - 35 batches submitted to accumulate stats from 2240 documents (108377 virtual)
# 2024-11-24 17:34:10,217 - INFO - 36 batches submitted to accumulate stats from 2304 documents (110660 virtual)
# 2024-11-24 17:34:10,218 - INFO - 37 batches submitted to accumulate stats from 2368 documents (112815 virtual)
# 2024-11-24 17:34:10,222 - INFO - 38 batches submitted to accumulate stats from 2432 documents (115643 virtual)
# 2024-11-24 17:34:10,227 - INFO - 39 batches submitted to accumulate stats from 2496 documents (118460 virtual)
# 2024-11-24 17:34:10,233 - INFO - 40 batches submitted to accumulate stats from 2560 documents (120832 virtual)
# 2024-11-24 17:34:10,235 - INFO - 41 batches submitted to accumulate stats from 2624 documents (123481 virtual)
# 2024-11-24 17:34:10,236 - INFO - 42 batches submitted to accumulate stats from 2688 documents (125736 virtual)
# 2024-11-24 17:34:10,237 - INFO - 43 batches submitted to accumulate stats from 2752 documents (128261 virtual)
# 2024-11-24 17:34:10,242 - INFO - 44 batches submitted to accumulate stats from 2816 documents (130505 virtual)
# 2024-11-24 17:34:10,244 - INFO - 45 batches submitted to accumulate stats from 2880 documents (133086 virtual)
# 2024-11-24 17:34:10,247 - INFO - 46 batches submitted to accumulate stats from 2944 documents (136104 virtual)
# 2024-11-24 17:34:10,251 - INFO - 47 batches submitted to accumulate stats from 3008 documents (140205 virtual)
# 2024-11-24 17:34:10,260 - INFO - 48 batches submitted to accumulate stats from 3072 documents (143418 virtual)
# 2024-11-24 17:34:10,271 - INFO - 49 batches submitted to accumulate stats from 3136 documents (148014 virtual)
# 2024-11-24 17:34:10,274 - INFO - 50 batches submitted to accumulate stats from 3200 documents (152022 virtual)
# 2024-11-24 17:34:10,277 - INFO - 51 batches submitted to accumulate stats from 3264 documents (156087 virtual)
# 2024-11-24 17:34:10,281 - INFO - 52 batches submitted to accumulate stats from 3328 documents (159897 virtual)
# 2024-11-24 17:34:10,283 - INFO - 53 batches submitted to accumulate stats from 3392 documents (164492 virtual)
# 2024-11-24 17:34:10,284 - INFO - 54 batches submitted to accumulate stats from 3456 documents (168758 virtual)
# 2024-11-24 17:34:10,287 - INFO - 55 batches submitted to accumulate stats from 3520 documents (171680 virtual)
# 2024-11-24 17:34:10,289 - INFO - 56 batches submitted to accumulate stats from 3584 documents (175247 virtual)
# 2024-11-24 17:34:10,293 - INFO - 57 batches submitted to accumulate stats from 3648 documents (176711 virtual)
# 2024-11-24 17:34:10,363 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 17:34:10,371 - INFO - accumulated word occurrence stats for 176939 virtual documents
# 2024-11-24 17:34:10,549 - INFO - 第 3 折评估完成: NPMI=0.4965, Diversity=0.4800, Optimal Score=0.4883
# 实验进度:   5%|▌         | 3/60 [00:07<02:24,  2.54s/it]2024-11-24 17:34:10,551 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 17:34:10,624 - INFO - built Dictionary<10238 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 208721 corpus positions)
# 2024-11-24 17:34:10,624 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<10238 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 208721 corpus positions)", 'datetime': '2024-11-24T17:34:10.624882', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:10,628 - INFO - discarding 10038 tokens: [('aegeus', 2), ('andreo', 12), ('declaro', 45), ('deus', 2088), ('dominicus', 61), ('epistula', 68), ('folium', 11), ('historia', 52), ('hora', 51), ('lombardicus', 3)]...
# 2024-11-24 17:34:10,629 - INFO - keeping 200 tokens which were in no less than 2 and no more than 1806 (=50.0%) documents
# 2024-11-24 17:34:10,630 - INFO - resulting dictionary: Dictionary<200 unique tokens: ['ada', 'apostolus', 'christus', 'considero', 'dominus']...>
# 2024-11-24 17:34:10,630 - INFO - 词典过滤: 10238 -> 200 个词
# 2024-11-24 17:34:10,668 - INFO - using symmetric alpha at 0.06666666666666667
# 2024-11-24 17:34:10,668 - INFO - using symmetric eta at 0.06666666666666667
# 2024-11-24 17:34:10,668 - INFO - using serial LDA version on this node
# 2024-11-24 17:34:10,669 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 17:34:10,669 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 17:34:10,669 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 17:34:10,972 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 17:34:10,972 - INFO - topic #13 (0.067): 0.043*"homo" + 0.042*"uita" + 0.041*"christus" + 0.027*"debeo" + 0.023*"uerbum" + 0.021*"dominus" + 0.018*"pater" + 0.017*"ueritas" + 0.016*"filius" + 0.015*"natura"
# 2024-11-24 17:34:10,972 - INFO - topic #8 (0.067): 0.091*"christus" + 0.036*"uerbum" + 0.024*"spiritus" + 0.018*"amo" + 0.018*"uirtus" + 0.016*"ueritas" + 0.015*"debeo" + 0.015*"fides" + 0.015*"homo" + 0.015*"amor"
# 2024-11-24 17:34:10,973 - INFO - topic #14 (0.067): 0.082*"spiritus" + 0.029*"christus" + 0.024*"anima" + 0.023*"peccatum" + 0.019*"homo" + 0.018*"uerbum" + 0.017*"scio" + 0.017*"sanctus" + 0.015*"cor" + 0.015*"uita"
# 2024-11-24 17:34:10,973 - INFO - topic #7 (0.067): 0.058*"spiritus" + 0.038*"uita" + 0.037*"anima" + 0.031*"uerbum" + 0.019*"audio" + 0.019*"sapientia" + 0.018*"uiuo" + 0.016*"christus" + 0.016*"amor" + 0.014*"uoluntas"
# 2024-11-24 17:34:10,973 - INFO - topic #9 (0.067): 0.034*"spiritus" + 0.034*"pater" + 0.031*"christus" + 0.029*"uita" + 0.027*"uerbum" + 0.025*"uirtus" + 0.022*"homo" + 0.020*"fides" + 0.019*"lumen" + 0.017*"filius"
# 2024-11-24 17:34:10,973 - INFO - topic diff=0.756087, rho=1.000000
# 2024-11-24 17:34:11,245 - INFO - -5.185 per-word bound, 36.4 perplexity estimate based on a held-out corpus of 1612 documents with 42555 words
# 2024-11-24 17:34:11,245 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 17:34:11,468 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 17:34:11,469 - INFO - topic #5 (0.067): 0.094*"filius" + 0.087*"pater" + 0.034*"caritas" + 0.029*"spiritus" + 0.023*"uirtus" + 0.020*"diligo" + 0.020*"principium" + 0.018*"unitas" + 0.018*"cognosco" + 0.015*"opus"
# 2024-11-24 17:34:11,469 - INFO - topic #13 (0.067): 0.057*"homo" + 0.048*"uita" + 0.041*"christus" + 0.033*"debeo" + 0.028*"iustitia" + 0.024*"dominus" + 0.020*"ratio" + 0.017*"uia" + 0.017*"uerbum" + 0.017*"ueritas"
# 2024-11-24 17:34:11,469 - INFO - topic #2 (0.067): 0.038*"panis" + 0.037*"uita" + 0.035*"christus" + 0.029*"debeo" + 0.028*"caelum" + 0.025*"lex" + 0.018*"homo" + 0.017*"tempus" + 0.016*"sanctus" + 0.016*"uenio"
# 2024-11-24 17:34:11,470 - INFO - topic #1 (0.067): 0.046*"dies" + 0.044*"nomen" + 0.041*"homo" + 0.039*"mundus" + 0.029*"spiritus" + 0.028*"sapientia" + 0.026*"motus" + 0.026*"lux" + 0.025*"corpus" + 0.019*"natura"
# 2024-11-24 17:34:11,470 - INFO - topic #11 (0.067): 0.071*"christus" + 0.032*"iustitia" + 0.028*"homo" + 0.027*"filius" + 0.027*"natura" + 0.024*"lex" + 0.019*"gratia" + 0.018*"mater" + 0.018*"pax" + 0.015*"nascor"
# 2024-11-24 17:34:11,470 - INFO - topic diff=0.354750, rho=0.707107
# 2024-11-24 17:34:11,470 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=200, num_topics=15, decay=0.5, chunksize=2000> in 0.80s', 'datetime': '2024-11-24T17:34:11.470898', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:34:11,473 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 17:34:11,518 - INFO - 1 batches submitted to accumulate stats from 64 documents (4058 virtual)
# 2024-11-24 17:34:11,521 - INFO - 2 batches submitted to accumulate stats from 128 documents (7639 virtual)
# 2024-11-24 17:34:11,572 - INFO - 3 batches submitted to accumulate stats from 192 documents (11354 virtual)
# 2024-11-24 17:34:11,706 - INFO - 4 batches submitted to accumulate stats from 256 documents (15301 virtual)
# 2024-11-24 17:34:11,714 - INFO - 5 batches submitted to accumulate stats from 320 documents (19532 virtual)
# 2024-11-24 17:34:11,720 - INFO - 6 batches submitted to accumulate stats from 384 documents (23346 virtual)
# 2024-11-24 17:34:11,726 - INFO - 7 batches submitted to accumulate stats from 448 documents (27144 virtual)
# 2024-11-24 17:34:12,673 - INFO - 8 batches submitted to accumulate stats from 512 documents (31501 virtual)
# 2024-11-24 17:34:12,721 - INFO - 9 batches submitted to accumulate stats from 576 documents (36334 virtual)
# 2024-11-24 17:34:12,731 - INFO - 10 batches submitted to accumulate stats from 640 documents (39513 virtual)
# 2024-11-24 17:34:12,737 - INFO - 11 batches submitted to accumulate stats from 704 documents (44693 virtual)
# 2024-11-24 17:34:12,756 - INFO - 12 batches submitted to accumulate stats from 768 documents (48806 virtual)
# 2024-11-24 17:34:12,773 - INFO - 13 batches submitted to accumulate stats from 832 documents (52157 virtual)
# 2024-11-24 17:34:12,780 - INFO - 14 batches submitted to accumulate stats from 896 documents (54909 virtual)
# 2024-11-24 17:34:12,812 - INFO - 15 batches submitted to accumulate stats from 960 documents (57479 virtual)
# 2024-11-24 17:34:12,817 - INFO - 16 batches submitted to accumulate stats from 1024 documents (59295 virtual)
# 2024-11-24 17:34:13,058 - INFO - 17 batches submitted to accumulate stats from 1088 documents (61451 virtual)
# 2024-11-24 17:34:13,064 - INFO - 18 batches submitted to accumulate stats from 1152 documents (64213 virtual)
# 2024-11-24 17:34:13,087 - INFO - 19 batches submitted to accumulate stats from 1216 documents (66890 virtual)
# 2024-11-24 17:34:13,135 - INFO - 20 batches submitted to accumulate stats from 1280 documents (69789 virtual)
# 2024-11-24 17:34:13,190 - INFO - 21 batches submitted to accumulate stats from 1344 documents (71749 virtual)
# 2024-11-24 17:34:13,192 - INFO - 22 batches submitted to accumulate stats from 1408 documents (73990 virtual)
# 2024-11-24 17:34:13,210 - INFO - 23 batches submitted to accumulate stats from 1472 documents (76863 virtual)
# 2024-11-24 17:34:13,228 - INFO - 24 batches submitted to accumulate stats from 1536 documents (78884 virtual)
# 2024-11-24 17:34:13,230 - INFO - 25 batches submitted to accumulate stats from 1600 documents (82350 virtual)
# 2024-11-24 17:34:13,231 - INFO - 26 batches submitted to accumulate stats from 1664 documents (85151 virtual)
# 2024-11-24 17:34:13,233 - INFO - 27 batches submitted to accumulate stats from 1728 documents (87651 virtual)
# 2024-11-24 17:34:13,236 - INFO - 28 batches submitted to accumulate stats from 1792 documents (89984 virtual)
# 2024-11-24 17:34:13,243 - INFO - 29 batches submitted to accumulate stats from 1856 documents (92182 virtual)
# 2024-11-24 17:34:13,246 - INFO - 30 batches submitted to accumulate stats from 1920 documents (94470 virtual)
# 2024-11-24 17:34:13,255 - INFO - 31 batches submitted to accumulate stats from 1984 documents (96726 virtual)
# 2024-11-24 17:34:13,257 - INFO - 32 batches submitted to accumulate stats from 2048 documents (99473 virtual)
# 2024-11-24 17:34:13,272 - INFO - 33 batches submitted to accumulate stats from 2112 documents (101635 virtual)
# 2024-11-24 17:34:13,289 - INFO - 34 batches submitted to accumulate stats from 2176 documents (104541 virtual)
# 2024-11-24 17:34:13,292 - INFO - 35 batches submitted to accumulate stats from 2240 documents (108244 virtual)
# 2024-11-24 17:34:13,320 - INFO - 36 batches submitted to accumulate stats from 2304 documents (110693 virtual)
# 2024-11-24 17:34:13,345 - INFO - 37 batches submitted to accumulate stats from 2368 documents (112966 virtual)
# 2024-11-24 17:34:13,352 - INFO - 38 batches submitted to accumulate stats from 2432 documents (115636 virtual)
# 2024-11-24 17:34:13,354 - INFO - 39 batches submitted to accumulate stats from 2496 documents (118477 virtual)
# 2024-11-24 17:34:13,356 - INFO - 40 batches submitted to accumulate stats from 2560 documents (120674 virtual)
# 2024-11-24 17:34:13,359 - INFO - 41 batches submitted to accumulate stats from 2624 documents (123676 virtual)
# 2024-11-24 17:34:13,364 - INFO - 42 batches submitted to accumulate stats from 2688 documents (125813 virtual)
# 2024-11-24 17:34:13,367 - INFO - 43 batches submitted to accumulate stats from 2752 documents (128433 virtual)
# 2024-11-24 17:34:13,377 - INFO - 44 batches submitted to accumulate stats from 2816 documents (130969 virtual)
# 2024-11-24 17:34:13,388 - INFO - 45 batches submitted to accumulate stats from 2880 documents (133532 virtual)
# 2024-11-24 17:34:13,391 - INFO - 46 batches submitted to accumulate stats from 2944 documents (136086 virtual)
# 2024-11-24 17:34:13,398 - INFO - 47 batches submitted to accumulate stats from 3008 documents (140908 virtual)
# 2024-11-24 17:34:13,424 - INFO - 48 batches submitted to accumulate stats from 3072 documents (143563 virtual)
# 2024-11-24 17:34:13,430 - INFO - 49 batches submitted to accumulate stats from 3136 documents (148358 virtual)
# 2024-11-24 17:34:13,432 - INFO - 50 batches submitted to accumulate stats from 3200 documents (152180 virtual)
# 2024-11-24 17:34:13,448 - INFO - 51 batches submitted to accumulate stats from 3264 documents (156529 virtual)
# 2024-11-24 17:34:13,451 - INFO - 52 batches submitted to accumulate stats from 3328 documents (160526 virtual)
# 2024-11-24 17:34:13,453 - INFO - 53 batches submitted to accumulate stats from 3392 documents (164538 virtual)
# 2024-11-24 17:34:13,457 - INFO - 54 batches submitted to accumulate stats from 3456 documents (168497 virtual)
# 2024-11-24 17:34:13,471 - INFO - 55 batches submitted to accumulate stats from 3520 documents (171027 virtual)
# 2024-11-24 17:34:13,474 - INFO - 56 batches submitted to accumulate stats from 3584 documents (174581 virtual)
# 2024-11-24 17:34:13,478 - INFO - 57 batches submitted to accumulate stats from 3648 documents (176213 virtual)
# 2024-11-24 17:34:13,564 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 17:34:13,584 - INFO - accumulated word occurrence stats for 176416 virtual documents
# 2024-11-24 17:34:13,756 - INFO - 第 4 折评估完成: NPMI=0.4960, Diversity=0.4533, Optimal Score=0.4746
# 实验进度:   7%|▋         | 4/60 [00:10<02:37,  2.80s/it]2024-11-24 17:34:13,758 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 17:34:13,837 - INFO - built Dictionary<10358 unique tokens: ['ada', 'aegeus', 'andreo', 'apostolus', 'christus']...> from 3612 documents (total 210639 corpus positions)
# ...
# 2024-11-24 17:37:32,271 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 17:37:32,271 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 17:37:32,718 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 17:37:32,719 - INFO - topic #0 (0.067): 0.014*"debeo" + 0.013*"christus" + 0.012*"sanctus" + 0.010*"regnum" + 0.009*"uita" + 0.008*"caritas" + 0.008*"uirtus" + 0.008*"misericordia" + 0.007*"spiritus" + 0.007*"homo"
# 2024-11-24 17:37:32,720 - INFO - topic #8 (0.067): 0.025*"homo" + 0.020*"christus" + 0.015*"uerbum" + 0.012*"spiritus" + 0.011*"filius" + 0.011*"pater" + 0.010*"ueritas" + 0.009*"uirtus" + 0.008*"dominus" + 0.008*"mors"
# 2024-11-24 17:37:32,720 - INFO - topic #14 (0.067): 0.046*"spiritus" + 0.033*"uita" + 0.018*"ueritas" + 0.015*"christus" + 0.011*"anima" + 0.011*"natura" + 0.011*"amor" + 0.011*"filius" + 0.009*"uiuo" + 0.008*"homo"
# 2024-11-24 17:37:32,720 - INFO - topic #1 (0.067): 0.019*"christus" + 0.016*"pater" + 0.015*"mundus" + 0.015*"filius" + 0.012*"spiritus" + 0.010*"mors" + 0.010*"uita" + 0.009*"scio" + 0.008*"primus" + 0.008*"uerbum"
# 2024-11-24 17:37:32,721 - INFO - topic #3 (0.067): 0.034*"christus" + 0.015*"spiritus" + 0.013*"fides" + 0.011*"dominus" + 0.011*"debeo" + 0.011*"corpus" + 0.010*"homo" + 0.010*"anima" + 0.010*"credo" + 0.010*"uita"
# 2024-11-24 17:37:32,721 - INFO - topic diff=3.470189, rho=1.000000
# 2024-11-24 17:37:33,098 - INFO - -7.225 per-word bound, 149.6 perplexity estimate based on a held-out corpus of 1612 documents with 80402 words
# 2024-11-24 17:37:33,098 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 17:37:33,410 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 17:37:33,411 - INFO - topic #0 (0.067): 0.015*"debeo" + 0.014*"forma" + 0.013*"regnum" + 0.013*"sanctus" + 0.013*"christus" + 0.009*"misericordia" + 0.008*"dominus" + 0.008*"uirtus" + 0.008*"uirgo" + 0.007*"infinitus"
# 2024-11-24 17:37:33,412 - INFO - topic #14 (0.067): 0.070*"spiritus" + 0.040*"uita" + 0.021*"ueritas" + 0.016*"anima" + 0.014*"christus" + 0.011*"natura" + 0.011*"rationalis" + 0.011*"uiuo" + 0.010*"amor" + 0.010*"filius"
# 2024-11-24 17:37:33,412 - INFO - topic #3 (0.067): 0.043*"christus" + 0.018*"fides" + 0.015*"spiritus" + 0.012*"corpus" + 0.012*"debeo" + 0.012*"dominus" + 0.010*"uenio" + 0.010*"anima" + 0.010*"credo" + 0.010*"homo"
# 2024-11-24 17:37:33,412 - INFO - topic #5 (0.067): 0.019*"uerbum" + 0.015*"ars" + 0.015*"fides" + 0.015*"uirtus" + 0.012*"anima" + 0.011*"homo" + 0.009*"unitas" + 0.008*"pater" + 0.008*"filius" + 0.008*"sanctus"
# 2024-11-24 17:37:33,413 - INFO - topic #11 (0.067): 0.034*"christus" + 0.019*"uerbum" + 0.016*"filius" + 0.012*"homo" + 0.011*"spiritus" + 0.011*"mitto" + 0.010*"uenio" + 0.010*"credo" + 0.009*"pater" + 0.009*"lex"
# 2024-11-24 17:37:33,413 - INFO - topic diff=0.994615, rho=0.707107
# 2024-11-24 17:37:33,413 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=2000, num_topics=15, decay=0.5, chunksize=2000> in 1.14s', 'datetime': '2024-11-24T17:37:33.413683', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 17:37:33,416 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 17:37:33,867 - INFO - 1 batches submitted to accumulate stats from 64 documents (3955 virtual)
# 2024-11-24 17:37:33,870 - INFO - 2 batches submitted to accumulate stats from 128 documents (7752 virtual)
# 2024-11-24 17:37:33,872 - INFO - 3 batches submitted to accumulate stats from 192 documents (11737 virtual)
# 2024-11-24 17:37:33,874 - INFO - 4 batches submitted to accumulate stats from 256 documents (15801 virtual)
# 2024-11-24 17:37:33,875 - INFO - 5 batches submitted to accumulate stats from 320 documents (20210 virtual)
# 2024-11-24 17:37:33,890 - INFO - 6 batches submitted to accumulate stats from 384 documents (23855 virtual)
# 2024-11-24 17:37:33,892 - INFO - 7 batches submitted to accumulate stats from 448 documents (27736 virtual)
# 2024-11-24 17:37:34,564 - INFO - 8 batches submitted to accumulate stats from 512 documents (32245 virtual)
# 2024-11-24 17:37:34,618 - INFO - 9 batches submitted to accumulate stats from 576 documents (37177 virtual)
# 2024-11-24 17:37:34,678 - INFO - 10 batches submitted to accumulate stats from 640 documents (40670 virtual)
# 2024-11-24 17:37:34,734 - INFO - 11 batches submitted to accumulate stats from 704 documents (45568 virtual)
# 2024-11-24 17:37:34,792 - INFO - 12 batches submitted to accumulate stats from 768 documents (49798 virtual)
# 2024-11-24 17:37:34,809 - INFO - 13 batches submitted to accumulate stats from 832 documents (53241 virtual)
# 2024-11-24 17:37:34,833 - INFO - 14 batches submitted to accumulate stats from 896 documents (56199 virtual)
# 2024-11-24 17:37:34,872 - INFO - 15 batches submitted to accumulate stats from 960 documents (58687 virtual)
# 2024-11-24 17:37:34,874 - INFO - 16 batches submitted to accumulate stats from 1024 documents (60420 virtual)
# 2024-11-24 17:37:34,880 - INFO - 17 batches submitted to accumulate stats from 1088 documents (62554 virtual)
# 2024-11-24 17:37:34,911 - INFO - 18 batches submitted to accumulate stats from 1152 documents (65337 virtual)
# 2024-11-24 17:37:34,913 - INFO - 19 batches submitted to accumulate stats from 1216 documents (67961 virtual)
# 2024-11-24 17:37:34,915 - INFO - 20 batches submitted to accumulate stats from 1280 documents (70623 virtual)
# 2024-11-24 17:37:34,917 - INFO - 21 batches submitted to accumulate stats from 1344 documents (72521 virtual)
# 2024-11-24 17:37:34,918 - INFO - 22 batches submitted to accumulate stats from 1408 documents (74869 virtual)
# 2024-11-24 17:37:34,920 - INFO - 23 batches submitted to accumulate stats from 1472 documents (77797 virtual)
# 2024-11-24 17:37:34,939 - INFO - 24 batches submitted to accumulate stats from 1536 documents (79685 virtual)
# 2024-11-24 17:37:34,951 - INFO - 25 batches submitted to accumulate stats from 1600 documents (82881 virtual)
# 2024-11-24 17:37:35,042 - INFO - 26 batches submitted to accumulate stats from 1664 documents (85809 virtual)
# 2024-11-24 17:37:35,056 - INFO - 27 batches submitted to accumulate stats from 1728 documents (88234 virtual)
# 2024-11-24 17:37:35,071 - INFO - 28 batches submitted to accumulate stats from 1792 documents (90552 virtual)
# 2024-11-24 17:37:35,076 - INFO - 29 batches submitted to accumulate stats from 1856 documents (92790 virtual)
# 2024-11-24 17:37:35,078 - INFO - 30 batches submitted to accumulate stats from 1920 documents (95205 virtual)
# 2024-11-24 17:37:35,084 - INFO - 31 batches submitted to accumulate stats from 1984 documents (97554 virtual)
# 2024-11-24 17:37:35,094 - INFO - 32 batches submitted to accumulate stats from 2048 documents (100131 virtual)
# 2024-11-24 17:37:35,095 - INFO - 33 batches submitted to accumulate stats from 2112 documents (102210 virtual)
# 2024-11-24 17:37:35,099 - INFO - 34 batches submitted to accumulate stats from 2176 documents (104878 virtual)
# 2024-11-24 17:37:35,102 - INFO - 35 batches submitted to accumulate stats from 2240 documents (108703 virtual)
# 2024-11-24 17:37:35,109 - INFO - 36 batches submitted to accumulate stats from 2304 documents (111081 virtual)
# 2024-11-24 17:37:35,111 - INFO - 37 batches submitted to accumulate stats from 2368 documents (113119 virtual)
# 2024-11-24 17:37:35,130 - INFO - 38 batches submitted to accumulate stats from 2432 documents (116382 virtual)
# 2024-11-24 17:37:35,132 - INFO - 39 batches submitted to accumulate stats from 2496 documents (119129 virtual)
# 2024-11-24 17:37:35,139 - INFO - 40 batches submitted to accumulate stats from 2560 documents (121364 virtual)
# 2024-11-24 17:37:35,141 - INFO - 41 batches submitted to accumulate stats from 2624 documents (123718 virtual)
# 2024-11-24 17:37:35,142 - INFO - 42 batches submitted to accumulate stats from 2688 documents (126258 virtual)
# 2024-11-24 17:37:35,144 - INFO - 43 batches submitted to accumulate stats from 2752 documents (129043 virtual)
# 2024-11-24 17:37:35,149 - INFO - 44 batches submitted to accumulate stats from 2816 documents (130916 virtual)
# 2024-11-24 17:37:35,159 - INFO - 45 batches submitted to accumulate stats from 2880 documents (133498 virtual)
# 2024-11-24 17:37:35,168 - INFO - 46 batches submitted to accumulate stats from 2944 documents (137395 virtual)
# 2024-11-24 17:37:35,173 - INFO - 47 batches submitted to accumulate stats from 3008 documents (140940 virtual)
# 2024-11-24 17:37:35,176 - INFO - 48 batches submitted to accumulate stats from 3072 documents (145203 virtual)
# 2024-11-24 17:37:35,189 - INFO - 49 batches submitted to accumulate stats from 3136 documents (149142 virtual)
# 2024-11-24 17:37:35,192 - INFO - 50 batches submitted to accumulate stats from 3200 documents (153697 virtual)
# 2024-11-24 17:37:35,195 - INFO - 51 batches submitted to accumulate stats from 3264 documents (157528 virtual)
# 2024-11-24 17:37:35,248 - INFO - 52 batches submitted to accumulate stats from 3328 documents (161385 virtual)
# 2024-11-24 17:37:35,287 - INFO - 53 batches submitted to accumulate stats from 3392 documents (166173 virtual)
# 2024-11-24 17:37:35,289 - INFO - 54 batches submitted to accumulate stats from 3456 documents (170006 virtual)
# 2024-11-24 17:37:35,291 - INFO - 55 batches submitted to accumulate stats from 3520 documents (172939 virtual)
# 2024-11-24 17:37:35,293 - INFO - 56 batches submitted to accumulate stats from 3584 documents (176652 virtual)
# 2024-11-24 17:37:35,294 - INFO - 57 batches submitted to accumulate stats from 3648 documents (178131 virtual)
# 2024-11-24 17:37:35,587 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 17:37:35,593 - INFO - accumulated word occurrence stats for 178337 virtual documents
# 2024-11-24 17:37:35,804 - INFO - 第 5 折评估完成: NPMI=0.5031, Diversity=0.4600, Optimal Score=0.4815
# 实验进度: 100%|██████████| 60/60 [03:32<00:00,  3.55s/it]
# 2024-11-24 17:37:35,821 - INFO - 已保存评估结果DataFrame
# 2024-11-24 17:37:35,823 - INFO - 已保存每折详细结果
# 2024-11-24 17:37:35,841 - INFO - 已保存主题词结果
# 2024-11-24 17:37:35,842 - INFO - 已保存最佳参数
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 35789 (\N{CJK UNIFIED IDEOGRAPH-8BCD}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 39057 (\N{CJK UNIFIED IDEOGRAPH-9891}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 38408 (\N{CJK UNIFIED IDEOGRAPH-9608}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 32452 (\N{CJK UNIFIED IDEOGRAPH-7EC4}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 20272 (\N{CJK UNIFIED IDEOGRAPH-4F30}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:20: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from current font.
#   plt.tight_layout()
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 35789 (\N{CJK UNIFIED IDEOGRAPH-8BCD}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 39057 (\N{CJK UNIFIED IDEOGRAPH-9891}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 38408 (\N{CJK UNIFIED IDEOGRAPH-9608}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 32452 (\N{CJK UNIFIED IDEOGRAPH-7EC4}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 21512 (\N{CJK UNIFIED IDEOGRAPH-5408}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 20272 (\N{CJK UNIFIED IDEOGRAPH-4F30}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# /var/folders/jj/84v_jpsx4rj3__y62xh3klxm0000gn/T/ipykernel_6115/3012458350.py:21: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from current font.
#   plt.savefig(os.path.join(experiment_dir, 'threshold_heatmap.png'))
# 实验结果已成功保存!
# 2024-11-24 17:37:36,104 - INFO - 已保存评估结果热力图
# 可视化结果已生成!
#
# 最佳参数组合:
# 最小词频阈值: 2
# 最大词频阈值: 200
# Optimal Score: 0.475

# %%
def visualize_metrics_trends(df, experiment_dir):
    """Create comprehensive visualization for all metrics"""
    plt.figure(figsize=(15, 8))
    
    # 创建阈值组合标签
    df['threshold_range'] = df['min_freq'].astype(str) + '-' + df['max_freq'].astype(str)
    
    # 计算每个阈值组合的平均指标值
    metrics_avg = df.groupby('threshold_range').agg({
        'npmi': 'mean',
        'diversity': 'mean',
        'optimal_score': 'mean'
    }).reset_index()
    
    # 排序以确保x轴顺序合理
    metrics_avg['min_freq'] = metrics_avg['threshold_range'].str.split('-').str[0].astype(int)
    metrics_avg['max_freq'] = metrics_avg['threshold_range'].str.split('-').str[1].astype(int)
    metrics_avg = metrics_avg.sort_values(['min_freq', 'max_freq'])
    
    # 绘制三个指标的折线
    plt.plot(metrics_avg['threshold_range'], metrics_avg['npmi'], 
            marker='o', label='NPMI', color='#FFA500', linewidth=2)
    plt.plot(metrics_avg['threshold_range'], metrics_avg['diversity'], 
            marker='s', label='Diversity', color='#FF6B6B', linewidth=2)
    plt.plot(metrics_avg['threshold_range'], metrics_avg['optimal_score'], 
            marker='^', label='Optimal Score', color='#4ECDC4', linewidth=2)
    
    # 设置图表格式
    plt.title('Relationship Between Threshold Range and Metrics', fontsize=14, pad=20)
    plt.xlabel('Threshold Range (min_freq-max_freq)', fontsize=12)
    plt.ylabel('Scores', fontsize=12)
    
    # 添加网格
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # 调整x轴标签
    plt.xticks(rotation=45, ha='right')
    
    # 添加图例
    plt.legend(loc='upper right')
    
    # 调整布局
    plt.tight_layout()
    
    # 保存图片
    plt.savefig(os.path.join(experiment_dir, 'metrics_trends.png'), 
                dpi=300, bbox_inches='tight')
    plt.close()
    
    # 打印最优组合
    best_combo = metrics_avg.loc[metrics_avg['optimal_score'].idxmax()]
    print(f"\nBest Parameter Combination:")
    print(f"Threshold Range: {best_combo['threshold_range']}")
    print(f"NPMI: {best_combo['npmi']:.4f}")
    print(f"Diversity: {best_combo['diversity']:.4f}")
    print(f"Optimal Score: {best_combo['optimal_score']:.4f}")

# 读取数据并生成可视化
df = pd.read_csv(os.path.join(experiment_dir, 'fold_results.csv'))
visualize_metrics_trends(df, experiment_dir)
print(f"Visualization saved in: {experiment_dir}/metrics_trends.png")
# Out:
# 2024-11-24 17:48:40,062 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-24 17:48:40,064 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-24 17:48:40,066 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-24 17:48:40,067 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-24 17:48:40,068 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-24 17:48:40,069 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Best Parameter Combination:
# Threshold Range: 2-200
# NPMI: 0.4966
# Diversity: 0.4533
# Optimal Score: 0.4750
# Visualization saved in: experiments/lda/spacy/frequency_filtered/experiment_20241124_173402/metrics_trends.png
