# %%
import os
import time
import logging
import json
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import silhouette_score
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from transformers import AutoTokenizer, AutoModel
import torch
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora
from tqdm import tqdm

# %%
# 检查 MPS 是否可用
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using MPS backend on Apple Silicon.")
else:
    device = torch.device("cpu")
    print("MPS backend not available, using CPU instead.")
# Out:
# Using MPS backend on Apple Silicon.

# %%
# 基础路径设置
BASE_DIR = '/Users/jessie/Documents/Projects/Cusanus_Topic_Modeling'

# 生成唯一实验ID
experiment_id = f"latinbert_{time.strftime('%Y%m%d%H%M%S')}"
experiment_dir = os.path.join(BASE_DIR, 'experiments', 'latinbert', experiment_id)

# 创建实验目录
if not os.path.exists(experiment_dir):
    os.makedirs(experiment_dir)

# 获取日志文件路径
log_file_path = os.path.join(experiment_dir, f"{experiment_id}.log")

# 配置日志记录
logger = logging.getLogger()
if logger.hasHandlers():
    logger.handlers.clear()
logger.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
file_handler = logging.FileHandler(log_file_path)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

logger.info(f"启动实验 {experiment_id}，日志记录到 {log_file_path}")
print(f"启动实验 {experiment_id}，日志记录到 {log_file_path}")
# Out:
# 2024-11-10 19:53:50,355 - INFO - 启动实验 latinbert_20241110195350，日志记录到 /Users/jessie/Documents/Projects/Cusanus_Topic_Modeling/experiments/latinbert/latinbert_20241110195350/latinbert_20241110195350.log
# 启动实验 latinbert_20241110195350，日志记录到 /Users/jessie/Documents/Projects/Cusanus_Topic_Modeling/experiments/latinbert/latinbert_20241110195350/latinbert_20241110195350.log

# %%
# 实验配置
experiment_config = {
    "parameters": {
        "n_gram_range": (1, 2),  # 捕捉更多的上下文短语
        "min_topic_size": 2,  # 增大最小主题大小以减少噪声
        "nr_topics": "auto",  # 自动确定主题数量
        "umap_params": {
            "n_neighbors": 10,  # 增加邻居数使得降维更平滑
            "min_dist": 0.1,  # 增大最小距离使主题更分离
            "n_components": 2,  # 增大维度以保留更多特征信息
            "random_state": 42  # 确保实验可重复
        }
    }
}

config_path = os.path.join(experiment_dir, 'config.json')
with open(config_path, 'w') as config_file:
    json.dump(experiment_config, config_file, indent=4)

logger.info(f"实验配置已保存到 {config_path}")
print(f"实验配置已保存到 {config_path}")
# Out:
# 2024-11-10 19:53:50,360 - INFO - 实验配置已保存到 /Users/jessie/Documents/Projects/Cusanus_Topic_Modeling/experiments/latinbert/latinbert_20241110195350/config.json
# 实验配置已保存到 /Users/jessie/Documents/Projects/Cusanus_Topic_Modeling/experiments/latinbert/latinbert_20241110195350/config.json

# %%
# 加载本地 Latin BERT 模型
logger.info("加载 Latin-BERT 嵌入模型...")
model_path = "/Users/jessie/Documents/Projects/Cusanus_Topic_Modeling/latin-bert/models/latin_bert"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModel.from_pretrained(model_path).to(device)
# Out:
# 2024-11-10 19:53:50,366 - INFO - 加载 Latin-BERT 嵌入模型...

# %%
# 定义嵌入生成函数
def get_latin_bert_embeddings(texts):
    tokens = tokenizer(texts, padding=True, truncation=True, return_tensors="pt", max_length=256).to(device)
    with torch.no_grad():
        embeddings = model(**tokens).last_hidden_state.mean(dim=1)
    return embeddings.cpu().numpy()

# %%
# 加载测试集文档
testset_dir = os.path.join(BASE_DIR, 'data/testset')
documents = []

logger.info("加载测试集数据...")
test_files = [f for f in os.listdir(testset_dir) if f.endswith('.txt')]
for test_file in tqdm(test_files, desc="Loading testset files"):
    file_path = os.path.join(testset_dir, test_file)
    with open(file_path, 'r', encoding='utf-8') as file:
        documents.append(file.read())

logger.info(f"加载了 {len(documents)} 个文档用于 BERTopic 实验。")
print(documents[:5])
# Out:
# 2024-11-10 19:53:51,963 - INFO - 加载测试集数据...
# Loading testset files: 100%|██████████| 61/61 [00:00<00:00, 1942.43it/s]
# 2024-11-10 19:53:52,093 - INFO - 加载了 61 个文档用于 BERTopic 实验。
# ['induimini dominus iesum christum romanus epistula dominicus quoad intellego aliqual iesus secundus adam filius deus andreas declaro aegeae lego his¬toria lombardica tertius folium considero epistula aposto¬lus hora somnus surgo probo apostolus dilectio com¬pletio lex prae¬cepto dilectio propior complicantur om¬nia quoad propior subjungo plenitudo lex dilectio scio hora somnus sur¬gere dilectio plenitudo lex scio surgen¬dum somnus vigilanter attenden¬dum propior salus credo expono tempus credo fides recipio salus mors christus conformabimur exspecto dico2 credo salus lex spiri¬tualiter intellego scien¬tes spiritual intellego dilectio¬nem propior salus unus mando1 dilectio adimpleo diligo nolo malus infero salus intel¬lectu diligo removeo difficilis potestas pauper dives nobilis ignobilis graecus barbaris diligo plenitu¬do lex deus adimplemus mandatum ser¬vamus vita ingredior salus magister veritas volo1 vita ingredior servo mandatum somnus sopor teneo dilectio plenitudo lex ignoro peccatum te¬nebra obfuscatio mens peccatum moueo inor¬dinatus amor moueo anima mo¬vetur ordino moveo rectus justus amo deus pro¬ximum inordinatus moveo reflexe curvus retorquendo om¬nia diligo finis con¬stituat surgo peccatum mortalis somnus orior spiritus calor desero2 expando exter contraho interior vigil verus dif¬fusio spiritus exter somnus di¬citur peccatum similitudo som¬nus immobilitat motus immobilitat sensus immobilitat ago immobilitat in¬fluxum moueo procedo cor prop¬ter finis finis bonus hiis finis sanitas bonus medicina cor¬pus indumentum gratia poenitentia peccatum immobilitat aufero mo¬tum deus finis ulter moueo homo finis dimitto constituo pec¬cator finis particularis luxuriosus luxuria moveo avarus pecunia superbus vanus gloria finis homo vilis peccatum aufero motus immobilitat sensus sensus rivulis procedo sentio com¬muni resideo primus pars cerebrum fumus ascendo cerebrum infrigidantur condenso claudeo spiritus rivulorum sensus2 immobilitatur sensus peccator sentio sensus tango iudico lenis1 pun¬git gustus iudico dulcis amaris olefactus sentio foe¬tor pecco puteo plenus foetor corpus sentio audio faber audio magnus clamor peccator deus mors praedicator ami¬cos audio ammonent lucidus judico tenebrosus bonus malus peccatum immobilitat ago som¬nus meritorium natural sci¬licet augeo nutrio rational sci¬licet consiliaris gubernaris publicus meritorium separo gratia deus mereo immobilitat influxum gra¬tiae caput ecclesia iesus corpus peccator membrum abscido corpus somnus pecco assimilatur ratio generatio ratio privatio ra¬tio operatio ratio apparitio genero somnus vapor as¬cendentibus occupatio spiritus evaporatio caro orior peccatum concupisco caro oculus superbia vita infrigidatur sensus communis somnus origo sensus2 peccator careo origo virtus meritor ratio privatio somnus homo privo actus intelligentiae ligo1 vireo1 animal pecco ma¬ximae luxuria intellego visio somnus appareo peccator visio ap¬paret bonus apostolus surgo dormio ex¬surge morior som¬num assimilaris pecco hora somnus surgo considero salus salvator venio salus radius illuminans nox tenebrae detineo radius dies efficio descendo sol recedo verbum sapientia pater sapientia magister illuminan¬dum discipulus nox ignorantia existen¬tes mens descendo medium verbum maneo magister sedeo tenebrae um¬bra mors lux orior magnus af¬fert laetitia radius illuminans dulcis delectabilis lumen oculus nox gravis infirmis dies alleviat venio salvator canto ambrosius1 hymnus dominicus advenio salvator infirmis iu¬cundissimus advenio sponsus sponsa sponsus procedo thalamus venio rex nos¬ter mansuetus abicio debeo opus te¬nebraris vitio fugio lu¬cem fur odi lux sordidus debe¬mus lavaris proicio tenebrosus nox induo splendidus arma lucus arma princeps tenebraris arma lucus veritas occurro debeo bene mundo orno arma splendeo rex dies natalis honestus ambulo debeo po¬nere festivitas advenio vita comessatio ebrietas cubilis vito anima esca potus2 gratia pax induo debeo iesum christum induo iesum c ...

# %%
# 嵌入生成
document_embeddings = get_latin_bert_embeddings(documents)

# %%
# 定义参数网格
param_grid = {
    'n_neighbors': [5, 10, 15],
    'min_dist': [0.0, 0.1, 0.5],
    'n_components': [2, 5, 10],
    'min_topic_size': [2, 5, 10],
    'nr_topics': ['auto', 10, 20]
}

# 创建参数组合
param_combinations = list(ParameterGrid(param_grid))

# 存储每次运行的结果
results = []

# %%
# 遍历每个参数组合
for params in param_combinations:
    logger.info(f"评估参数组合: {params}")
    
    # 创建 UMAP 和 BERTopic 模型
    custom_umap = UMAP(
        n_neighbors=params['n_neighbors'],
        min_dist=params['min_dist'],
        n_components=params['n_components'],
        random_state=42
    )
    
    topic_model = BERTopic(
        embedding_model=None,
        vectorizer_model=CountVectorizer(ngram_range=experiment_config["parameters"]["n_gram_range"]),
        umap_model=custom_umap,
        min_topic_size=params['min_topic_size'],
        nr_topics=params['nr_topics'],
        language=None
    )
    
    # 训练模型
    topics, probabilities = topic_model.fit_transform(documents, embeddings=document_embeddings)
    
    # 提取每个主题的前10个关键词
    bertopic_topics = []
    for topic_num in range(len(topic_model.get_topics())):
        topic = topic_model.get_topic(topic_num)
        if topic:  # 确保 topic 不是布尔值
            bertopic_topics.append([word for word, _ in topic])
    
    # 使用 gensim.corpora.Dictionary 创建词典
    texts = [doc.split() for doc in documents]
    dictionary = corpora.Dictionary(texts)
    
    # 计算主题一致性（NPMI）
    coherence_model_npmi = CoherenceModel(topics=bertopic_topics, texts=texts, dictionary=dictionary, coherence='c_npmi')
    coherence_score_npmi = coherence_model_npmi.get_coherence()
    
    # 计算主题多样性
    unique_words = set()
    total_words = 0
    for topic in bertopic_topics:
        unique_words.update(topic)
        total_words += len(topic)
    topic_diversity = len(unique_words) / total_words
    
    # 计算 WEPS 评分
    def get_average_embedding_for_topic(topic_words, tokenizer, model, device):
        tokens = tokenizer(topic_words, padding=True, truncation=True, return_tensors="pt", max_length=256).to(device)
        with torch.no_grad():
            embeddings = model(**tokens).last_hidden_state.mean(dim=1)
        return embeddings.cpu().numpy()

    topic_embeddings = []
    for topic in bertopic_topics:
        topic_embedding = get_average_embedding_for_topic(topic, tokenizer, model, device)
        topic_embeddings.append(topic_embedding)
    topic_embeddings = np.concatenate(topic_embeddings)
    similarity_matrix = cosine_similarity(topic_embeddings)
    weps = np.mean(similarity_matrix)
    
    silhouette_avg = silhouette_score(document_embeddings, topics)
    
    # 存储结果
    results.append({
        'params': params,
        'coherence_score_npmi': coherence_score_npmi,
        'topic_diversity': topic_diversity,
        'weps': weps,
        'silhouette_score': silhouette_avg
    })

# 找到最优的参数组合
best_result = max(results, key=lambda x: (x['coherence_score_npmi'], x['topic_diversity'], x['weps'], x['silhouette_score']))

# 输出最优结果
logger.info(f"最优参数组合: {best_result['params']}")
print(f"最优参数组合: {best_result['params']}")

# 保存最优参数
params_path = os.path.join(experiment_dir, 'best_params.json')
with open(params_path, 'w') as f:
    json.dump(best_result['params'], f, indent=4)
logger.info(f"最优参数已保存至 {params_path}")
# Out:
# 2024-11-10 19:53:56,506 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 'auto'}
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 2024-11-10 19:54:01,581 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:01,604 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:01,604 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:01.604500', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:01,606 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:05,536 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:05,815 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:05,820 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:07,529 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 10}
# 2024-11-10 19:54:08,001 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:08,024 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:08,024 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:08.024892', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:08,026 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:11,208 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:11,491 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:11,494 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:11,857 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 20}
# 2024-11-10 19:54:12,238 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:12,260 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:12,261 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:12.261079', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:12,263 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:15,549 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:15,892 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:15,895 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:16,397 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 10, 'nr_topics': 'auto'}
# 2024-11-10 19:54:16,878 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:16,901 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:16,901 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:16.901516', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:16,903 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:20,169 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:20,421 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:20,424 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:20,625 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 10, 'nr_topics': 10}
# 2024-11-10 19:54:20,990 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:21,013 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:21,014 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:21.014365', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:21,016 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:24,195 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:24,436 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:24,439 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:24,648 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 10, 'nr_topics': 20}
# 2024-11-10 19:54:25,025 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:25,047 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:25,048 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:25.048032', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:25,049 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:28,217 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:28,501 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:28,504 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:28,914 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 15, 'nr_topics': 'auto'}
# 2024-11-10 19:54:29,473 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:29,495 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:29,495 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:29.495831', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:29,497 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:32,802 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:33,070 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:33,074 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:33,519 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 15, 'nr_topics': 10}
# 2024-11-10 19:54:33,874 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:33,896 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:33,897 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:33.897158', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:33,898 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:37,190 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:37,479 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:37,483 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:37,930 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 2, 'n_neighbors': 15, 'nr_topics': 20}
# 2024-11-10 19:54:38,289 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:38,313 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:38,314 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:38.313999', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:38,315 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:41,567 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:41,831 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:41,833 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:42,275 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 5, 'n_neighbors': 5, 'nr_topics': 'auto'}
# 2024-11-10 19:54:42,712 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:42,735 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:42,736 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:42.736188', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:42,738 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:46,130 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:46,464 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:46,469 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:46,916 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 5, 'n_neighbors': 5, 'nr_topics': 10}
# 2024-11-10 19:54:47,274 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:47,298 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:47,299 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:47.299328', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:47,301 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:51,211 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:51,498 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:51,501 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:51,961 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 5, 'n_neighbors': 5, 'nr_topics': 20}
# 2024-11-10 19:54:52,350 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:52,376 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:52,377 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:52.377425', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:52,379 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:54:55,722 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:54:55,971 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:54:55,974 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:54:56,396 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 5, 'n_neighbors': 10, 'nr_topics': 'auto'}
# 2024-11-10 19:54:56,842 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:54:56,864 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:54:56,864 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:54:56.864798', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:54:56,866 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 19:55:00,249 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 19:55:00,583 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 19:55:00,587 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 19:55:01,015 - INFO - 评估参数组合: {'min_dist': 0.0, 'min_topic_size': 2, 'n_components': 5, 'n_neighbors': 10, 'nr_topics': 10}
# 2024-11-10 19:55:01,387 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 19:55:01,409 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 19:55:01,410 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T19:55:01.410441', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 19:55:01,412 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# ...
# 2024-11-10 20:11:05,412 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 20:11:05,439 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 20:11:05,439 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T20:11:05.439822', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 20:11:05,442 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 20:11:09,307 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 20:11:09,570 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 20:11:09,574 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 20:11:09,958 - INFO - 评估参数组合: {'min_dist': 0.5, 'min_topic_size': 10, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 'auto'}
# 2024-11-10 20:11:10,420 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 20:11:10,444 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 20:11:10,445 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T20:11:10.444971', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 20:11:10,447 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 20:11:14,108 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 20:11:14,356 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 20:11:14,358 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 20:11:14,672 - INFO - 评估参数组合: {'min_dist': 0.5, 'min_topic_size': 10, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 10}
# 2024-11-10 20:11:15,010 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 20:11:15,033 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 20:11:15,033 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T20:11:15.033856', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 20:11:15,035 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 20:11:18,694 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 20:11:18,956 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 20:11:18,959 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 20:11:19,279 - INFO - 评估参数组合: {'min_dist': 0.5, 'min_topic_size': 10, 'n_components': 2, 'n_neighbors': 5, 'nr_topics': 20}
# 2024-11-10 20:11:19,631 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-10 20:11:19,655 - INFO - built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)
# 2024-11-10 20:11:19,655 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<9286 unique tokens: ['abicio', 'abscido', 'achaia', 'actus', 'adae']...> from 61 documents (total 52171 corpus positions)", 'datetime': '2024-11-10T20:11:19.655522', 'gensim': '4.3.3', 'python': '3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-10 20:11:19,657 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-10 20:11:23,176 - INFO - 1 batches submitted to accumulate stats from 64 documents (51622 virtual)
# 2024-11-10 20:11:23,416 - INFO - 7 accumulators retrieved from output queue
# 2024-11-10 20:11:23,419 - INFO - accumulated word occurrence stats for 51622 virtual documents
# 2024-11-10 20:11:23,739 - INFO - 评估参数组合: {'min_dist': 0.5, 'min_topic_size': 10, 'n_components': 2, 'n_neighbors': 10, 'nr_topics': 'auto'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 23
#      13 topic_model = BERTopic(
#      14     embedding_model=None,
#      15     vectorizer_model=CountVectorizer(ngram_range=experiment_config["parameters"]["n_gram_range"]),
#    (...)
#      19     language=None
#      20 )
#      22 # 训练模型
# ---> 23 topics, probabilities = topic_model.fit_transform(documents, embeddings=document_embeddings)
#      25 # 提取每个主题的前10个关键词
#      26 bertopic_topics = []
#
# File ~/miniforge3/envs/latinbert_env/lib/python3.10/site-packages/bertopic/_bertopic.py:497, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     495 # Reduce topics
#     496 if self.nr_topics:
# --> 497     documents = self._reduce_topics(documents)
#     499 # Save the top 3 most representative documents per topic
#     500 self._save_representative_docs(documents)
#
# File ~/miniforge3/envs/latinbert_env/lib/python3.10/site-packages/bertopic/_bertopic.py:4354, in BERTopic._reduce_topics(self, documents, use_ctfidf)
#    4352         documents = self._reduce_to_n_topics(documents, use_ctfidf)
#    4353 elif isinstance(self.nr_topics, str):
# -> 4354     documents = self._auto_reduce_topics(documents, use_ctfidf)
#    4355 else:
#    4356     raise ValueError("nr_topics needs to be an int or 'auto'! ")
#
# File ~/miniforge3/envs/latinbert_env/lib/python3.10/site-packages/bertopic/_bertopic.py:4433, in BERTopic._auto_reduce_topics(self, documents, use_ctfidf)
#    4431 topics = documents.Topic.tolist().copy()
#    4432 unique_topics = sorted(list(documents.Topic.unique()))[self._outliers :]
# -> 4433 max_topic = unique_topics[-1]
#    4435 # Find similar topics
#    4436 embeddings = select_topic_representation(
#    4437     self.c_tf_idf_, self.topic_embeddings_, use_ctfidf, output_ndarray=True
#    4438 )[0]
#
# IndexError: list index out of range

# %%
# 保存评估结果和主题词
results_file_path = os.path.join(experiment_dir, 'bertopic_results.txt')
with open(results_file_path, 'w', encoding='utf-8') as f:
    # 保存主题词
    f.write("BERTopic 生成的主题：\n")
    for idx, topic in enumerate(bertopic_topics):
        topic_str = f"Topic {idx}: {', '.join(topic)}"
        f.write(topic_str + '\n')
    f.write("\n")
    
    # 保存评估结果
    f.write(f"平均主题一致性 (NPMI): {best_result['coherence_score_npmi']}\n")
    f.write(f"主题多样性: {best_result['topic_diversity']}\n")
    f.write(f"WEPS: {best_result['weps']}\n")
    f.write(f"轮廓系数: {best_result['silhouette_score']}\n")

logger.info(f"生成的主题和评估结果已保存至 {results_file_path}")
print(f"生成的主题和评估结果已保存至 {results_file_path}")
