# %%
import os
import spacy
import pandas as pd
import numpy as np
from gensim import corpora, models
from sklearn.model_selection import KFold
from collections import Counter
from tqdm import tqdm
import logging
import re
from datetime import datetime

# 设置工作目录和路径
base_dir = "/Users/jessie/Documents/Projects/Cusanus_Topic_Modeling"
os.chdir(base_dir)

# 设置日志
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
log_dir = 'experiments/lda/spacy/results'
os.makedirs(log_dir, exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'{log_dir}/lda_experiment_{timestamp}.log'),
        logging.StreamHandler()
    ]
)

# %%
def prepare_corpus_and_dictionary():
    """准备词典和语料库，处理带段落标记的文本"""
    logging.info("Preparing corpus and dictionary...")
    
    # 1. 加载spaCy模型
    try:
        nlp = spacy.load('models/la_core_web_lg-0.1.0-py3-none-any.whl')
    except:
        logging.info("Trying to load la_core_web_lg model directly...")
        nlp = spacy.load('la_core_web_lg')
    
    # 2. 读取所有预处理文件
    source_dir = 'experiments/lda/spacy/preprocessed'
    
    def is_valid_word(word):
        """检查词是否有效"""
        return (not bool(re.search(r'\d', word)) and 
                not all(char in '.,;:!?"\'()[]{}' for char in word) and 
                len(word.strip()) > 0)
    
    # 3. 处理文档并构建词频统计
    word_stats = Counter()
    all_texts = []
    paragraph_info = []  # 存储段落信息
    
    logging.info("Processing documents and building vocabulary...")
    for file in tqdm(os.listdir(source_dir)):
        if file.endswith('.txt'):
            with open(os.path.join(source_dir, file), 'r', encoding='utf-8') as f:
                content = f.read()
                # 按段落分割
                paragraphs = re.split(r'Paragraph \d+:\n', content)[1:]  # 跳过第一个空分割
                
                for para_idx, para in enumerate(paragraphs, 1):
                    para = para.strip()
                    if para:  # 忽略空段落
                        doc = nlp(para)
                        valid_words = [token.text.lower() for token in doc 
                                     if not token.is_stop and 
                                     not token.is_punct and 
                                     is_valid_word(token.text.lower())]
                        
                        if valid_words:  # 只添加非空段落
                            all_texts.append(valid_words)
                            word_stats.update(valid_words)
                            paragraph_info.append({
                                'file': file,
                                'paragraph_idx': para_idx,
                                'text': para,
                                'words': valid_words
                            })
    
    # 4. 筛选词频在2-200之间的词
    valid_words = {word for word, count in word_stats.items() 
                  if 2 <= count <= 200}
    
    # 5. 基于有效词汇过滤文档
    filtered_texts = [[word for word in text if word in valid_words] 
                     for text in all_texts]
    
    # 6. 创建词典和语料库
    dictionary = corpora.Dictionary(filtered_texts)
    corpus = [dictionary.doc2bow(text) for text in filtered_texts]
    
    logging.info(f"Total documents: {len(corpus)}")
    logging.info(f"Total paragraphs: {len(paragraph_info)}")
    logging.info(f"Vocabulary size: {len(dictionary)}")
    
    # 7. 保存段落信息
    pd.DataFrame(paragraph_info).to_csv(
        f'{log_dir}/paragraph_info_{timestamp}.csv', 
        index=False
    )
    
    return dictionary, corpus, filtered_texts, paragraph_info

def normalize_npmi(npmi):
    """将NPMI标准化到[0,1]区间"""
    return (npmi + 1) / 2

def normalize_diversity(diversity):
    """确保diversity在[0,1]区间内"""
    return max(0, min(1, diversity))

def evaluate_model(model, corpus, dictionary, texts):
    """评估LDA模型的NPMI和多样性，处理极端值"""
    try:
        # 计算NPMI
        coherence_model = models.coherencemodel.CoherenceModel(
            model=model, 
            texts=texts,
            dictionary=dictionary,
            coherence='c_npmi'
        )
        npmi = coherence_model.get_coherence()
        
        # 处理NPMI的极端值和无效值
        if np.isinf(npmi) or np.isnan(npmi):
            npmi = -1.0  # 设置一个默认的最低值
        
        # 确保NPMI在[-1, 1]范围内
        npmi = max(-1.0, min(1.0, npmi))
        
        # 标准化NPMI到[0,1]区间
        npmi_normalized = (npmi + 1) / 2
        
        # 计算主题多样性
        topics = model.show_topics(formatted=False)
        unique_words = set()
        total_words = 0
        for topic_id, topic in topics:
            words = [w for w, _ in topic]
            unique_words.update(words)
            total_words += len(words)
        
        # 确保diversity在[0,1]区间内
        diversity = max(0.0, min(1.0, len(unique_words) / total_words))
        
        # 最终检查确保返回值都是有效的浮点数
        if np.isinf(npmi_normalized) or np.isnan(npmi_normalized):
            npmi_normalized = 0.0
        if np.isinf(diversity) or np.isnan(diversity):
            diversity = 0.0
            
        logging.info(f"Evaluation metrics - NPMI: {npmi_normalized:.4f}, Diversity: {diversity:.4f}")
        
        return float(npmi_normalized), float(diversity)
    
    except Exception as e:
        logging.error(f"Error in evaluate_model: {str(e)}")
        # 发生错误时返回默认值
        return 0.0, 0.0

# %%
def run_lda_experiment(dictionary, corpus, texts, paragraph_info, k=5):
    """运行LDA实验并保存详细结果"""
    # 定义参数搜索空间
    num_topics_range = [10, 15]
    alpha_range = ['symmetric', 0.1, 0.3, 0.5]
    eta_range = ['symmetric', 0.1, 0.3, 0.5]
    
    # 创建结果列表
    experiment_results = []
    topic_words_results = []
    paragraph_topic_results = []
    
    experiment_id = 1  # 为每个实验添加唯一ID
    
    # 创建KFold对象
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    
    total_experiments = len(num_topics_range) * len(alpha_range) * len(eta_range)
    logging.info(f"Starting {total_experiments} experiments with {k} folds each")
    
    for num_topics in num_topics_range:
        for alpha in alpha_range:
            for eta in eta_range:
                logging.info(f"Running experiment {experiment_id}/{total_experiments}: "
                           f"topics={num_topics}, alpha={alpha}, eta={eta}")
                
                # 存储每个fold的结果
                fold_scores = []
                
                # 获取所有fold的划分
                fold_splits = list(kf.split(corpus))
                
                for fold, (train_idx, val_idx) in enumerate(fold_splits):
                    logging.info(f"Processing fold {fold+1}/{k}")
                    
                    # 准备训练和验证数据
                    train_corpus = [corpus[i] for i in train_idx]
                    val_corpus = [corpus[i] for i in val_idx]
                    val_texts = [texts[i] for i in val_idx]
                    
                    try:
                        # 训练模型
                        model = models.LdaModel(
                            corpus=train_corpus,
                            id2word=dictionary,
                            num_topics=num_topics,
                            alpha=alpha,
                            eta=eta,
                            random_state=42
                        )
                        
                        # 评估模型
                        npmi, diversity = evaluate_model(model, val_corpus, dictionary, val_texts)
                        optimal_score = 0.5 * npmi + 0.5 * diversity
                        
                        # 保存fold结果
                        fold_scores.append({
                            'experiment_id': experiment_id,
                            'fold': fold,
                            'npmi': npmi,
                            'diversity': diversity,
                            'optimal_score': optimal_score
                        })
                        
                        # 保存主题词
                        for topic_id, topic in model.show_topics(formatted=False):
                            topic_words_results.append({
                                'experiment_id': experiment_id,
                                'fold': fold,
                                'num_topics': num_topics,
                                'alpha': str(alpha),
                                'eta': str(eta),
                                'topic_id': topic_id,
                                'words': ', '.join([word for word, _ in topic]),
                                'word_probs': ', '.join([f"{prob:.4f}" for _, prob in topic])
                            })
                        
                        # 保存段落主题分配
                        for idx, bow in enumerate(val_corpus):
                            topic_dist = model.get_document_topics(bow)
                            main_topic = max(topic_dist, key=lambda x: x[1]) if topic_dist else (-1, 0)
                            paragraph_topic_results.append({
                                'experiment_id': experiment_id,
                                'fold': fold,
                                'paragraph_id': val_idx[idx],
                                'file': paragraph_info[val_idx[idx]]['file'],
                                'paragraph_idx': paragraph_info[val_idx[idx]]['paragraph_idx'],
                                'main_topic': main_topic[0],
                                'topic_prob': main_topic[1],
                                'topic_distribution': str(dict(topic_dist))
                            })
                            
                    except Exception as e:
                        logging.error(f"Error in experiment {experiment_id}, fold {fold}: {str(e)}")
                        continue
                
                # 计算平均分数
                if fold_scores:
                    avg_scores = pd.DataFrame(fold_scores).mean()
                    experiment_results.append({
                        'experiment_id': experiment_id,
                        'num_topics': num_topics,
                        'alpha': str(alpha),
                        'eta': str(eta),
                        'avg_npmi': avg_scores['npmi'],
                        'avg_diversity': avg_scores['diversity'],
                        'avg_optimal_score': avg_scores['optimal_score'],
                        'fold_count': len(fold_scores)
                    })
                
                # 保存中间结果
                if experiment_results:
                    pd.DataFrame(experiment_results).to_csv(
                        f'{log_dir}/intermediate_results_{timestamp}.csv', 
                        index=False
                    )
                
                experiment_id += 1
    
    # 创建最终的DataFrame
    results_df = pd.DataFrame(experiment_results)
    topic_words_df = pd.DataFrame(topic_words_results)
    paragraph_topics_df = pd.DataFrame(paragraph_topic_results)
    
    # 保存所有结果
    results_df.to_csv(f'{log_dir}/experiment_results_{timestamp}.csv', index=False)
    topic_words_df.to_csv(f'{log_dir}/topic_words_{timestamp}.csv', index=False)
    paragraph_topics_df.to_csv(f'{log_dir}/paragraph_topics_{timestamp}.csv', index=False)
    
    return results_df, topic_words_df, paragraph_topics_df

# 主执行流程
if __name__ == "__main__":
    try:
        # 1. 准备数据
        logging.info("Preparing corpus and dictionary...")
        dictionary, corpus, texts, paragraph_info = prepare_corpus_and_dictionary()
        
        # 2. 运行实验
        logging.info("Starting LDA experiments...")
        results_df, topic_words_df, paragraph_topics_df = run_lda_experiment(
            dictionary, corpus, texts, paragraph_info
        )
        
        # 3. 显示最佳结果
        best_result = results_df.loc[results_df['avg_optimal_score'].idxmax()]
        logging.info("\nBest Model Configuration:")
        logging.info(f"Experiment ID: {best_result['experiment_id']}")
        logging.info(f"Number of Topics: {best_result['num_topics']}")
        logging.info(f"Alpha: {best_result['alpha']}")
        logging.info(f"Eta: {best_result['eta']}")
        logging.info(f"Average NPMI: {best_result['avg_npmi']:.4f}")
        logging.info(f"Average Diversity: {best_result['avg_diversity']:.4f}")
        logging.info(f"Average Optimal Score: {best_result['avg_optimal_score']:.4f}")
        
        # 4. 保存最佳结果的主题词
        best_topics = topic_words_df[
            topic_words_df['experiment_id'] == best_result['experiment_id']
        ]
        best_topics.to_csv(f'{log_dir}/best_topics_{timestamp}.csv', index=False)
        
    except Exception as e:
        logging.error(f"Error occurred: {str(e)}", exc_info=True)
# Out:
# 2024-11-24 18:54:33,251 - INFO - Preparing corpus and dictionary...
# 2024-11-24 18:54:33,251 - INFO - Preparing corpus and dictionary...
# 2024-11-24 18:54:33,253 - INFO - Trying to load la_core_web_lg model directly...
# 2024-11-24 18:54:35,610 - INFO - Processing documents and building vocabulary...
# 100%|██████████| 306/306 [01:50<00:00,  2.77it/s]
# 2024-11-24 18:56:26,066 - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2024-11-24 18:56:26,130 - INFO - built Dictionary<7048 unique tokens: ['aegeus', 'andreo', 'declaro', 'dominicus', 'epistula']...> from 4515 documents (total 124220 corpus positions)
# 2024-11-24 18:56:26,130 - INFO - Dictionary lifecycle event {'msg': "built Dictionary<7048 unique tokens: ['aegeus', 'andreo', 'declaro', 'dominicus', 'epistula']...> from 4515 documents (total 124220 corpus positions)", 'datetime': '2024-11-24T18:56:26.130885', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:26,177 - INFO - Total documents: 4515
# 2024-11-24 18:56:26,178 - INFO - Total paragraphs: 4515
# 2024-11-24 18:56:26,178 - INFO - Vocabulary size: 7048
# 2024-11-24 18:56:26,260 - INFO - Starting LDA experiments...
# 2024-11-24 18:56:26,261 - INFO - Starting 32 experiments with 5 folds each
# 2024-11-24 18:56:26,261 - INFO - Running experiment 1/32: topics=10, alpha=symmetric, eta=symmetric
# 2024-11-24 18:56:26,269 - INFO - Processing fold 1/5
# 2024-11-24 18:56:26,270 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:26,270 - INFO - using symmetric eta at 0.1
# 2024-11-24 18:56:26,271 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:26,276 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:26,276 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:26,277 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:26,598 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:26,602 - INFO - topic #3 (0.100): 0.007*"pastor" + 0.004*"arbor" + 0.004*"medio" + 0.004*"mortalis" + 0.004*"interior" + 0.004*"sabbatum" + 0.003*"beatitudo" + 0.003*"ouis" + 0.003*"ostium" + 0.003*"reuelo"
# 2024-11-24 18:56:26,603 - INFO - topic #7 (0.100): 0.010*"pastor" + 0.007*"ouis" + 0.006*"dimitto" + 0.005*"felicitas" + 0.004*"malum" + 0.004*"arbor" + 0.003*"uinco" + 0.003*"substantia" + 0.003*"animal" + 0.003*"plenus"
# 2024-11-24 18:56:26,603 - INFO - topic #0 (0.100): 0.009*"consummo" + 0.009*"trinitas" + 0.005*"pateo" + 0.004*"summus" + 0.004*"abraha" + 0.004*"abscondo" + 0.003*"lignum" + 0.003*"bonitas" + 0.003*"crux" + 0.003*"plenus"
# 2024-11-24 18:56:26,603 - INFO - topic #9 (0.100): 0.006*"pulcher" + 0.005*"lapis" + 0.004*"manifesto" + 0.004*"comprehendo" + 0.004*"aurum" + 0.004*"esurio" + 0.004*"calor" + 0.004*"consummo" + 0.003*"sanctifico" + 0.003*"medio"
# 2024-11-24 18:56:26,604 - INFO - topic #2 (0.100): 0.005*"crux" + 0.004*"poena" + 0.004*"judaeus" + 0.004*"pastor" + 0.003*"johannus" + 0.003*"libero" + 0.003*"passio" + 0.003*"crucifigo" + 0.003*"seruio" + 0.003*"annuntio"
# 2024-11-24 18:56:26,604 - INFO - topic diff=6.145248, rho=1.000000
# 2024-11-24 18:56:26,887 - INFO - -9.611 per-word bound, 782.1 perplexity estimate based on a held-out corpus of 1612 documents with 44206 words
# 2024-11-24 18:56:26,887 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:27,096 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:27,099 - INFO - topic #1 (0.100): 0.005*"naturalis" + 0.004*"complico" + 0.004*"quiesco" + 0.004*"plenitudo" + 0.003*"wir" + 0.003*"rego" + 0.003*"thesaurus" + 0.003*"contineo" + 0.003*"operatio" + 0.003*"emo"
# 2024-11-24 18:56:27,099 - INFO - topic #5 (0.100): 0.007*"wir" + 0.006*"sponsus" + 0.006*"conuenio" + 0.005*"quaestio" + 0.005*"got" + 0.004*"tango" + 0.004*"seruus" + 0.004*"sponsa" + 0.004*"uater" + 0.004*"aetas"
# 2024-11-24 18:56:27,099 - INFO - topic #9 (0.100): 0.008*"ferrum" + 0.008*"lapis" + 0.006*"aurum" + 0.006*"quies" + 0.005*"pulcher" + 0.004*"leprosus" + 0.004*"color" + 0.004*"sano" + 0.004*"sanctifico" + 0.004*"fons"
# 2024-11-24 18:56:27,100 - INFO - topic #8 (0.100): 0.006*"uitis" + 0.006*"seruus" + 0.004*"trado" + 0.004*"pauper" + 0.004*"aufero" + 0.004*"causa" + 0.003*"indigeo" + 0.003*"labor" + 0.003*"cura" + 0.003*"acquiro"
# 2024-11-24 18:56:27,101 - INFO - topic #2 (0.100): 0.006*"fons" + 0.005*"deficio" + 0.004*"judaeus" + 0.004*"praecedo" + 0.004*"libero" + 0.003*"gaudeo" + 0.003*"crux" + 0.003*"annuntio" + 0.003*"poena" + 0.003*"aduentus"
# 2024-11-24 18:56:27,101 - INFO - topic diff=0.729046, rho=0.707107
# 2024-11-24 18:56:27,101 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.83s', 'datetime': '2024-11-24T18:56:27.101624', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:27,104 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:30,481 - INFO - 1 batches submitted to accumulate stats from 64 documents (1691 virtual)
# 2024-11-24 18:56:30,484 - INFO - 2 batches submitted to accumulate stats from 128 documents (2991 virtual)
# 2024-11-24 18:56:30,485 - INFO - 3 batches submitted to accumulate stats from 192 documents (5136 virtual)
# 2024-11-24 18:56:30,487 - INFO - 4 batches submitted to accumulate stats from 256 documents (6261 virtual)
# 2024-11-24 18:56:30,488 - INFO - 5 batches submitted to accumulate stats from 320 documents (6836 virtual)
# 2024-11-24 18:56:30,491 - INFO - 6 batches submitted to accumulate stats from 384 documents (7536 virtual)
# 2024-11-24 18:56:30,497 - INFO - 7 batches submitted to accumulate stats from 448 documents (8497 virtual)
# 2024-11-24 18:56:30,500 - INFO - 8 batches submitted to accumulate stats from 512 documents (9190 virtual)
# 2024-11-24 18:56:30,502 - INFO - 9 batches submitted to accumulate stats from 576 documents (10163 virtual)
# 2024-11-24 18:56:30,505 - INFO - 10 batches submitted to accumulate stats from 640 documents (11092 virtual)
# 2024-11-24 18:56:30,508 - INFO - 11 batches submitted to accumulate stats from 704 documents (12014 virtual)
# 2024-11-24 18:56:30,511 - INFO - 12 batches submitted to accumulate stats from 768 documents (13307 virtual)
# 2024-11-24 18:56:30,515 - INFO - 13 batches submitted to accumulate stats from 832 documents (15253 virtual)
# 2024-11-24 18:56:30,517 - INFO - 14 batches submitted to accumulate stats from 896 documents (16969 virtual)
# 2024-11-24 18:56:30,518 - INFO - 15 batches submitted to accumulate stats from 960 documents (17191 virtual)
# 2024-11-24 18:56:30,570 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:30,583 - INFO - accumulated word occurrence stats for 17565 virtual documents
# 2024-11-24 18:56:30,679 - INFO - Evaluation metrics - NPMI: 0.2720, Diversity: 0.9100
# 2024-11-24 18:56:30,807 - INFO - Processing fold 2/5
# 2024-11-24 18:56:30,809 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:30,809 - INFO - using symmetric eta at 0.1
# 2024-11-24 18:56:30,810 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:30,813 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:30,813 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:30,814 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:31,128 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:31,130 - INFO - topic #3 (0.100): 0.007*"pastor" + 0.004*"ostium" + 0.004*"reuelo" + 0.004*"mortalis" + 0.003*"ouis" + 0.003*"medio" + 0.003*"cesso" + 0.003*"figura" + 0.003*"calor" + 0.003*"arbor"
# 2024-11-24 18:56:31,131 - INFO - topic #7 (0.100): 0.005*"pastor" + 0.005*"substantia" + 0.005*"dimitto" + 0.004*"ouis" + 0.004*"arbor" + 0.004*"facies" + 0.004*"persona" + 0.003*"lignum" + 0.003*"produco" + 0.003*"felicitas"
# 2024-11-24 18:56:31,131 - INFO - topic #0 (0.100): 0.008*"trinitas" + 0.006*"consummo" + 0.005*"bonitas" + 0.004*"perdo" + 0.004*"poena" + 0.004*"crux" + 0.004*"lignum" + 0.003*"aduerto" + 0.003*"pateo" + 0.003*"summus"
# 2024-11-24 18:56:31,132 - INFO - topic #9 (0.100): 0.007*"consummo" + 0.005*"aurum" + 0.005*"calor" + 0.004*"manifesto" + 0.004*"fecunditas" + 0.004*"pulcher" + 0.003*"medio" + 0.003*"nexus" + 0.003*"comprehendo" + 0.003*"lapis"
# 2024-11-24 18:56:31,132 - INFO - topic #2 (0.100): 0.004*"crux" + 0.004*"pastor" + 0.004*"passio" + 0.004*"judaeus" + 0.003*"seruio" + 0.003*"animal" + 0.003*"johannus" + 0.003*"eleuo" + 0.003*"substantia" + 0.003*"plenus"
# 2024-11-24 18:56:31,132 - INFO - topic diff=6.115588, rho=1.000000
# 2024-11-24 18:56:31,395 - INFO - -9.632 per-word bound, 793.5 perplexity estimate based on a held-out corpus of 1612 documents with 45002 words
# 2024-11-24 18:56:31,395 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:31,606 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:31,608 - INFO - topic #1 (0.100): 0.007*"magnes" + 0.005*"complico" + 0.005*"aequalitas" + 0.004*"naturalis" + 0.003*"ager" + 0.003*"aurum" + 0.003*"participo" + 0.003*"mensura" + 0.003*"aeternitas" + 0.003*"quiesco"
# 2024-11-24 18:56:31,608 - INFO - topic #5 (0.100): 0.004*"benedico" + 0.004*"got" + 0.004*"sto" + 0.004*"abraham" + 0.004*"praesens" + 0.004*"dignus" + 0.004*"sponsus" + 0.004*"lebens" + 0.003*"populus" + 0.003*"gens"
# 2024-11-24 18:56:31,609 - INFO - topic #9 (0.100): 0.008*"ferrum" + 0.007*"stella" + 0.007*"consummo" + 0.007*"quies" + 0.005*"aurum" + 0.005*"lapis" + 0.004*"pes" + 0.004*"luna" + 0.004*"leprosus" + 0.004*"complementum"
# 2024-11-24 18:56:31,609 - INFO - topic #8 (0.100): 0.005*"exspecto" + 0.004*"timeo" + 0.004*"aufero" + 0.004*"seruus" + 0.003*"trado" + 0.003*"causa" + 0.003*"nolo" + 0.003*"diues" + 0.003*"religio" + 0.003*"mortalis"
# 2024-11-24 18:56:31,610 - INFO - topic #2 (0.100): 0.006*"fons" + 0.005*"deficio" + 0.004*"judaeus" + 0.004*"pastor" + 0.004*"animal" + 0.004*"annuntio" + 0.003*"littera" + 0.003*"ciuitas" + 0.003*"plenus" + 0.003*"subicio"
# 2024-11-24 18:56:31,610 - INFO - topic diff=0.735457, rho=0.707107
# 2024-11-24 18:56:31,611 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.80s', 'datetime': '2024-11-24T18:56:31.611072', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:31,613 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:34,381 - INFO - 1 batches submitted to accumulate stats from 64 documents (1453 virtual)
# 2024-11-24 18:56:34,383 - INFO - 2 batches submitted to accumulate stats from 128 documents (3256 virtual)
# 2024-11-24 18:56:34,385 - INFO - 3 batches submitted to accumulate stats from 192 documents (4979 virtual)
# 2024-11-24 18:56:34,386 - INFO - 4 batches submitted to accumulate stats from 256 documents (6014 virtual)
# 2024-11-24 18:56:34,387 - INFO - 5 batches submitted to accumulate stats from 320 documents (6966 virtual)
# 2024-11-24 18:56:34,389 - INFO - 6 batches submitted to accumulate stats from 384 documents (7619 virtual)
# 2024-11-24 18:56:34,393 - INFO - 7 batches submitted to accumulate stats from 448 documents (8530 virtual)
# 2024-11-24 18:56:34,395 - INFO - 8 batches submitted to accumulate stats from 512 documents (9158 virtual)
# 2024-11-24 18:56:34,397 - INFO - 9 batches submitted to accumulate stats from 576 documents (10323 virtual)
# 2024-11-24 18:56:34,399 - INFO - 10 batches submitted to accumulate stats from 640 documents (11215 virtual)
# 2024-11-24 18:56:34,401 - INFO - 11 batches submitted to accumulate stats from 704 documents (11990 virtual)
# 2024-11-24 18:56:34,402 - INFO - 12 batches submitted to accumulate stats from 768 documents (13162 virtual)
# 2024-11-24 18:56:34,404 - INFO - 13 batches submitted to accumulate stats from 832 documents (14839 virtual)
# 2024-11-24 18:56:34,406 - INFO - 14 batches submitted to accumulate stats from 896 documents (16236 virtual)
# 2024-11-24 18:56:34,406 - INFO - 15 batches submitted to accumulate stats from 960 documents (16369 virtual)
# 2024-11-24 18:56:34,443 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:34,453 - INFO - accumulated word occurrence stats for 16729 virtual documents
# 2024-11-24 18:56:34,586 - INFO - Evaluation metrics - NPMI: 0.2713, Diversity: 0.9000
# 2024-11-24 18:56:34,711 - INFO - Processing fold 3/5
# 2024-11-24 18:56:34,713 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:34,713 - INFO - using symmetric eta at 0.1
# 2024-11-24 18:56:34,714 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:34,717 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:34,717 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:34,717 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:35,032 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:35,034 - INFO - topic #3 (0.100): 0.010*"pastor" + 0.006*"ouis" + 0.004*"medio" + 0.004*"mortalis" + 0.003*"puto" + 0.003*"interior" + 0.003*"arbor" + 0.003*"cesso" + 0.003*"johannus" + 0.003*"reuelo"
# 2024-11-24 18:56:35,035 - INFO - topic #7 (0.100): 0.005*"pastor" + 0.004*"substantia" + 0.004*"uinco" + 0.004*"produco" + 0.004*"persona" + 0.003*"dimitto" + 0.003*"johannus" + 0.003*"ouis" + 0.003*"arbor" + 0.003*"felicitas"
# 2024-11-24 18:56:35,035 - INFO - topic #0 (0.100): 0.008*"trinitas" + 0.005*"bonitas" + 0.004*"perdo" + 0.004*"pateo" + 0.003*"originalis" + 0.003*"summus" + 0.003*"manifesto" + 0.003*"abscondo" + 0.003*"aeternitas" + 0.003*"aduerto"
# 2024-11-24 18:56:35,035 - INFO - topic #9 (0.100): 0.006*"manifesto" + 0.005*"lapis" + 0.005*"consummo" + 0.004*"color" + 0.004*"pulcher" + 0.004*"perhibeo" + 0.003*"calor" + 0.003*"aurum" + 0.003*"medio" + 0.003*"requiro"
# 2024-11-24 18:56:35,036 - INFO - topic #2 (0.100): 0.004*"poena" + 0.004*"crux" + 0.003*"pastor" + 0.003*"seruio" + 0.003*"judaeus" + 0.003*"libero" + 0.003*"tenebrae" + 0.003*"promissio" + 0.003*"animal" + 0.003*"sponsus"
# 2024-11-24 18:56:35,036 - INFO - topic diff=6.093802, rho=1.000000
# 2024-11-24 18:56:35,300 - INFO - -9.623 per-word bound, 788.3 perplexity estimate based on a held-out corpus of 1612 documents with 44813 words
# 2024-11-24 18:56:35,300 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:35,518 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:35,520 - INFO - topic #1 (0.100): 0.006*"magnes" + 0.005*"naturalis" + 0.005*"complico" + 0.004*"participo" + 0.004*"operatio" + 0.004*"ferrum" + 0.003*"quiesco" + 0.003*"corporalis" + 0.003*"proximus" + 0.003*"oboedientia"
# 2024-11-24 18:56:35,521 - INFO - topic #5 (0.100): 0.005*"abraham" + 0.005*"sponsus" + 0.004*"quaestio" + 0.004*"octauus" + 0.004*"abraha" + 0.004*"dignus" + 0.004*"benedictio" + 0.003*"gens" + 0.003*"sponsa" + 0.003*"benedico"
# 2024-11-24 18:56:35,521 - INFO - topic #9 (0.100): 0.007*"lapis" + 0.006*"ferrum" + 0.005*"respondeo" + 0.005*"consummo" + 0.005*"color" + 0.005*"manifesto" + 0.005*"aurum" + 0.005*"leprosus" + 0.004*"quies" + 0.004*"multitudo"
# 2024-11-24 18:56:35,521 - INFO - topic #8 (0.100): 0.007*"seruus" + 0.005*"ignoro" + 0.004*"nolo" + 0.004*"exspecto" + 0.004*"trado" + 0.004*"superbia" + 0.004*"causa" + 0.004*"indigeo" + 0.003*"census" + 0.003*"labor"
# 2024-11-24 18:56:35,522 - INFO - topic #2 (0.100): 0.004*"daemonium" + 0.004*"fons" + 0.004*"judaeus" + 0.004*"annuntio" + 0.003*"sponsus" + 0.003*"animal" + 0.003*"colo" + 0.003*"glacies" + 0.003*"gaudeo" + 0.003*"deficio"
# 2024-11-24 18:56:35,522 - INFO - topic diff=0.728246, rho=0.707107
# 2024-11-24 18:56:35,523 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.81s', 'datetime': '2024-11-24T18:56:35.523034', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:35,525 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:38,354 - INFO - 1 batches submitted to accumulate stats from 64 documents (1402 virtual)
# 2024-11-24 18:56:38,356 - INFO - 2 batches submitted to accumulate stats from 128 documents (3254 virtual)
# 2024-11-24 18:56:38,358 - INFO - 3 batches submitted to accumulate stats from 192 documents (5226 virtual)
# 2024-11-24 18:56:38,359 - INFO - 4 batches submitted to accumulate stats from 256 documents (5959 virtual)
# 2024-11-24 18:56:38,361 - INFO - 5 batches submitted to accumulate stats from 320 documents (6732 virtual)
# 2024-11-24 18:56:38,363 - INFO - 6 batches submitted to accumulate stats from 384 documents (7525 virtual)
# 2024-11-24 18:56:38,365 - INFO - 7 batches submitted to accumulate stats from 448 documents (8520 virtual)
# 2024-11-24 18:56:38,367 - INFO - 8 batches submitted to accumulate stats from 512 documents (9211 virtual)
# 2024-11-24 18:56:38,370 - INFO - 9 batches submitted to accumulate stats from 576 documents (10264 virtual)
# 2024-11-24 18:56:38,374 - INFO - 10 batches submitted to accumulate stats from 640 documents (11160 virtual)
# 2024-11-24 18:56:38,376 - INFO - 11 batches submitted to accumulate stats from 704 documents (12022 virtual)
# 2024-11-24 18:56:38,378 - INFO - 12 batches submitted to accumulate stats from 768 documents (13096 virtual)
# 2024-11-24 18:56:38,380 - INFO - 13 batches submitted to accumulate stats from 832 documents (15159 virtual)
# 2024-11-24 18:56:38,381 - INFO - 14 batches submitted to accumulate stats from 896 documents (16480 virtual)
# 2024-11-24 18:56:38,382 - INFO - 15 batches submitted to accumulate stats from 960 documents (16644 virtual)
# 2024-11-24 18:56:38,415 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:38,428 - INFO - accumulated word occurrence stats for 16975 virtual documents
# /Users/jessie/miniforge3/envs/cusanus_env/lib/python3.10/site-packages/gensim/topic_coherence/direct_confirmation_measure.py:204: RuntimeWarning: divide by zero encountered in scalar divide
#   m_lr_i = np.log(numerator / denominator)
# 2024-11-24 18:56:38,561 - INFO - Evaluation metrics - NPMI: 0.0000, Diversity: 0.9300
# 2024-11-24 18:56:38,681 - INFO - Processing fold 4/5
# 2024-11-24 18:56:38,682 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:38,683 - INFO - using symmetric eta at 0.1
# 2024-11-24 18:56:38,683 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:38,686 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:38,687 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:38,687 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:39,015 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:39,018 - INFO - topic #3 (0.100): 0.008*"pastor" + 0.004*"ouis" + 0.004*"interior" + 0.003*"reuelo" + 0.003*"ostium" + 0.003*"puto" + 0.003*"johannus" + 0.003*"respicio" + 0.003*"lapis" + 0.003*"arbor"
# 2024-11-24 18:56:39,018 - INFO - topic #7 (0.100): 0.006*"pastor" + 0.006*"dimitto" + 0.005*"substantia" + 0.005*"arbor" + 0.004*"ouis" + 0.003*"felicitas" + 0.003*"malum" + 0.003*"facies" + 0.003*"animal" + 0.003*"produco"
# 2024-11-24 18:56:39,019 - INFO - topic #0 (0.100): 0.006*"trinitas" + 0.004*"consummo" + 0.004*"perdo" + 0.003*"felicitas" + 0.003*"crux" + 0.003*"abscondo" + 0.003*"plenus" + 0.003*"aduerto" + 0.003*"summus" + 0.003*"abraha"
# 2024-11-24 18:56:39,019 - INFO - topic #9 (0.100): 0.005*"pulcher" + 0.005*"lapis" + 0.005*"manifesto" + 0.005*"aurum" + 0.004*"calor" + 0.004*"color" + 0.004*"stella" + 0.003*"respondeo" + 0.003*"crux" + 0.003*"consummo"
# 2024-11-24 18:56:39,020 - INFO - topic #2 (0.100): 0.005*"crux" + 0.004*"judaeus" + 0.004*"annuntio" + 0.003*"johannus" + 0.003*"tenebrae" + 0.003*"eleuo" + 0.003*"poena" + 0.003*"libero" + 0.003*"passio" + 0.003*"gentilis"
# 2024-11-24 18:56:39,020 - INFO - topic diff=6.114135, rho=1.000000
# 2024-11-24 18:56:39,293 - INFO - -9.560 per-word bound, 754.9 perplexity estimate based on a held-out corpus of 1612 documents with 44583 words
# 2024-11-24 18:56:39,294 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:39,502 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:39,503 - INFO - topic #1 (0.100): 0.006*"magnes" + 0.004*"complico" + 0.004*"naturalis" + 0.004*"aeternitas" + 0.004*"ferrum" + 0.004*"mensura" + 0.003*"quiesco" + 0.003*"participo" + 0.003*"emo" + 0.003*"appeto"
# 2024-11-24 18:56:39,504 - INFO - topic #5 (0.100): 0.007*"wir" + 0.006*"sponsus" + 0.006*"sponsa" + 0.005*"dignus" + 0.004*"circumcisio" + 0.004*"quaestio" + 0.004*"got" + 0.004*"capitulum" + 0.003*"lebens" + 0.003*"unser"
# 2024-11-24 18:56:39,504 - INFO - topic #9 (0.100): 0.007*"stella" + 0.006*"multitudo" + 0.005*"leprosus" + 0.005*"quies" + 0.005*"pulcher" + 0.005*"color" + 0.005*"respondeo" + 0.005*"lapis" + 0.004*"simplex" + 0.004*"manifesto"
# 2024-11-24 18:56:39,505 - INFO - topic #8 (0.100): 0.007*"uitis" + 0.006*"seruus" + 0.004*"aufero" + 0.004*"diues" + 0.004*"acquiro" + 0.004*"labor" + 0.004*"fons" + 0.003*"trado" + 0.003*"tango" + 0.003*"diuitia"
# 2024-11-24 18:56:39,505 - INFO - topic #2 (0.100): 0.005*"fons" + 0.005*"judaeus" + 0.004*"colo" + 0.004*"crux" + 0.003*"annuntio" + 0.003*"regno" + 0.003*"immortalitas" + 0.003*"libero" + 0.003*"deficio" + 0.003*"respicio"
# 2024-11-24 18:56:39,506 - INFO - topic diff=0.726162, rho=0.707107
# 2024-11-24 18:56:39,506 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.82s', 'datetime': '2024-11-24T18:56:39.506429', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:39,509 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:42,363 - INFO - 1 batches submitted to accumulate stats from 64 documents (1683 virtual)
# 2024-11-24 18:56:42,366 - INFO - 2 batches submitted to accumulate stats from 128 documents (3556 virtual)
# 2024-11-24 18:56:42,368 - INFO - 3 batches submitted to accumulate stats from 192 documents (5396 virtual)
# 2024-11-24 18:56:42,370 - INFO - 4 batches submitted to accumulate stats from 256 documents (6529 virtual)
# 2024-11-24 18:56:42,371 - INFO - 5 batches submitted to accumulate stats from 320 documents (7157 virtual)
# 2024-11-24 18:56:42,373 - INFO - 6 batches submitted to accumulate stats from 384 documents (7931 virtual)
# 2024-11-24 18:56:42,375 - INFO - 7 batches submitted to accumulate stats from 448 documents (8801 virtual)
# 2024-11-24 18:56:42,376 - INFO - 8 batches submitted to accumulate stats from 512 documents (9571 virtual)
# 2024-11-24 18:56:42,379 - INFO - 9 batches submitted to accumulate stats from 576 documents (10450 virtual)
# 2024-11-24 18:56:42,381 - INFO - 10 batches submitted to accumulate stats from 640 documents (11337 virtual)
# 2024-11-24 18:56:42,384 - INFO - 11 batches submitted to accumulate stats from 704 documents (11957 virtual)
# 2024-11-24 18:56:42,386 - INFO - 12 batches submitted to accumulate stats from 768 documents (13361 virtual)
# 2024-11-24 18:56:42,389 - INFO - 13 batches submitted to accumulate stats from 832 documents (14854 virtual)
# 2024-11-24 18:56:42,397 - INFO - 14 batches submitted to accumulate stats from 896 documents (17117 virtual)
# 2024-11-24 18:56:42,399 - INFO - 15 batches submitted to accumulate stats from 960 documents (17163 virtual)
# 2024-11-24 18:56:42,449 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:42,458 - INFO - accumulated word occurrence stats for 17536 virtual documents
# 2024-11-24 18:56:42,591 - INFO - Evaluation metrics - NPMI: 0.2726, Diversity: 0.9400
# 2024-11-24 18:56:42,710 - INFO - Processing fold 5/5
# 2024-11-24 18:56:42,711 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:42,712 - INFO - using symmetric eta at 0.1
# 2024-11-24 18:56:42,713 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:42,715 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:42,716 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:42,716 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:43,028 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:43,030 - INFO - topic #3 (0.100): 0.009*"pastor" + 0.005*"ostium" + 0.004*"ouis" + 0.004*"medio" + 0.003*"concupiscentia" + 0.003*"respicio" + 0.003*"mortalis" + 0.003*"interior" + 0.003*"subdo" + 0.003*"calor"
# 2024-11-24 18:56:43,030 - INFO - topic #7 (0.100): 0.006*"dimitto" + 0.005*"ouis" + 0.005*"pastor" + 0.004*"substantia" + 0.004*"manifesto" + 0.004*"facies" + 0.003*"johannus" + 0.003*"pes" + 0.003*"felicitas" + 0.003*"oboedientia"
# 2024-11-24 18:56:43,031 - INFO - topic #0 (0.100): 0.009*"trinitas" + 0.006*"consummo" + 0.004*"pateo" + 0.004*"poena" + 0.004*"bonitas" + 0.003*"crux" + 0.003*"manifesto" + 0.003*"felicitas" + 0.003*"abscondo" + 0.003*"summus"
# 2024-11-24 18:56:43,031 - INFO - topic #9 (0.100): 0.006*"consummo" + 0.005*"lapis" + 0.005*"aurum" + 0.005*"comprehendo" + 0.004*"calor" + 0.004*"esurio" + 0.003*"stella" + 0.003*"pulcher" + 0.003*"manifesto" + 0.003*"respondeo"
# 2024-11-24 18:56:43,031 - INFO - topic #2 (0.100): 0.004*"crux" + 0.004*"pastor" + 0.004*"passio" + 0.004*"tenebrae" + 0.004*"libero" + 0.003*"substantia" + 0.003*"poena" + 0.003*"nouus" + 0.003*"judaeus" + 0.003*"exprimo"
# 2024-11-24 18:56:43,032 - INFO - topic diff=6.113915, rho=1.000000
# 2024-11-24 18:56:43,300 - INFO - -9.638 per-word bound, 796.5 perplexity estimate based on a held-out corpus of 1612 documents with 45181 words
# 2024-11-24 18:56:43,300 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:43,513 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:43,515 - INFO - topic #1 (0.100): 0.007*"magnes" + 0.004*"quiesco" + 0.004*"operatio" + 0.004*"complico" + 0.004*"plenitudo" + 0.004*"ager" + 0.003*"naturalis" + 0.003*"rego" + 0.003*"oboedientia" + 0.003*"septimus"
# 2024-11-24 18:56:43,515 - INFO - topic #5 (0.100): 0.004*"benedico" + 0.004*"abraham" + 0.004*"seruus" + 0.004*"capitulum" + 0.004*"desero" + 0.003*"dubius" + 0.003*"quaestio" + 0.003*"templum" + 0.003*"abraha" + 0.003*"gens"
# 2024-11-24 18:56:43,516 - INFO - topic #9 (0.100): 0.009*"ferrum" + 0.007*"aurum" + 0.007*"stella" + 0.006*"lapis" + 0.006*"calor" + 0.005*"quies" + 0.005*"consummo" + 0.004*"animal" + 0.004*"respondeo" + 0.004*"multitudo"
# 2024-11-24 18:56:43,516 - INFO - topic #8 (0.100): 0.005*"trado" + 0.005*"exspecto" + 0.004*"uitis" + 0.004*"nolo" + 0.004*"census" + 0.004*"seruus" + 0.004*"pauper" + 0.004*"complaceo" + 0.004*"labor" + 0.003*"necessitas"
# 2024-11-24 18:56:43,517 - INFO - topic #2 (0.100): 0.006*"fons" + 0.004*"sponsus" + 0.004*"annuntio" + 0.004*"plenus" + 0.004*"deficio" + 0.004*"exprimo" + 0.004*"tenebrae" + 0.003*"judaeus" + 0.003*"laetitia" + 0.003*"nouus"
# 2024-11-24 18:56:43,517 - INFO - topic diff=0.738985, rho=0.707107
# 2024-11-24 18:56:43,518 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.80s', 'datetime': '2024-11-24T18:56:43.518005', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:43,520 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:46,740 - INFO - 1 batches submitted to accumulate stats from 64 documents (1579 virtual)
# 2024-11-24 18:56:46,743 - INFO - 2 batches submitted to accumulate stats from 128 documents (3279 virtual)
# 2024-11-24 18:56:46,745 - INFO - 3 batches submitted to accumulate stats from 192 documents (4936 virtual)
# 2024-11-24 18:56:46,747 - INFO - 4 batches submitted to accumulate stats from 256 documents (5833 virtual)
# 2024-11-24 18:56:46,751 - INFO - 5 batches submitted to accumulate stats from 320 documents (6808 virtual)
# 2024-11-24 18:56:46,756 - INFO - 6 batches submitted to accumulate stats from 384 documents (7690 virtual)
# 2024-11-24 18:56:46,763 - INFO - 7 batches submitted to accumulate stats from 448 documents (8552 virtual)
# 2024-11-24 18:56:46,765 - INFO - 8 batches submitted to accumulate stats from 512 documents (9221 virtual)
# 2024-11-24 18:56:46,768 - INFO - 9 batches submitted to accumulate stats from 576 documents (10377 virtual)
# 2024-11-24 18:56:46,770 - INFO - 10 batches submitted to accumulate stats from 640 documents (11026 virtual)
# 2024-11-24 18:56:46,773 - INFO - 11 batches submitted to accumulate stats from 704 documents (11940 virtual)
# 2024-11-24 18:56:46,776 - INFO - 12 batches submitted to accumulate stats from 768 documents (12869 virtual)
# 2024-11-24 18:56:46,781 - INFO - 13 batches submitted to accumulate stats from 832 documents (14715 virtual)
# 2024-11-24 18:56:46,783 - INFO - 14 batches submitted to accumulate stats from 896 documents (16046 virtual)
# 2024-11-24 18:56:46,784 - INFO - 15 batches submitted to accumulate stats from 960 documents (16218 virtual)
# 2024-11-24 18:56:46,850 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:46,858 - INFO - accumulated word occurrence stats for 16603 virtual documents
# 2024-11-24 18:56:46,991 - INFO - Evaluation metrics - NPMI: 0.0000, Diversity: 0.9200
# 2024-11-24 18:56:47,119 - INFO - Running experiment 2/32: topics=10, alpha=symmetric, eta=0.1
# 2024-11-24 18:56:47,120 - INFO - Processing fold 1/5
# 2024-11-24 18:56:47,121 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:47,122 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:47,124 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:47,125 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:47,125 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:47,447 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:47,449 - INFO - topic #3 (0.100): 0.007*"pastor" + 0.004*"arbor" + 0.004*"medio" + 0.004*"mortalis" + 0.004*"interior" + 0.004*"sabbatum" + 0.003*"beatitudo" + 0.003*"ouis" + 0.003*"ostium" + 0.003*"reuelo"
# 2024-11-24 18:56:47,449 - INFO - topic #7 (0.100): 0.010*"pastor" + 0.007*"ouis" + 0.006*"dimitto" + 0.005*"felicitas" + 0.004*"malum" + 0.004*"arbor" + 0.003*"uinco" + 0.003*"substantia" + 0.003*"animal" + 0.003*"plenus"
# 2024-11-24 18:56:47,449 - INFO - topic #0 (0.100): 0.009*"consummo" + 0.009*"trinitas" + 0.005*"pateo" + 0.004*"summus" + 0.004*"abraha" + 0.004*"abscondo" + 0.003*"lignum" + 0.003*"bonitas" + 0.003*"crux" + 0.003*"plenus"
# 2024-11-24 18:56:47,450 - INFO - topic #9 (0.100): 0.006*"pulcher" + 0.005*"lapis" + 0.004*"manifesto" + 0.004*"comprehendo" + 0.004*"aurum" + 0.004*"esurio" + 0.004*"calor" + 0.004*"consummo" + 0.003*"sanctifico" + 0.003*"medio"
# 2024-11-24 18:56:47,450 - INFO - topic #2 (0.100): 0.005*"crux" + 0.004*"poena" + 0.004*"judaeus" + 0.004*"pastor" + 0.003*"johannus" + 0.003*"libero" + 0.003*"passio" + 0.003*"crucifigo" + 0.003*"seruio" + 0.003*"annuntio"
# 2024-11-24 18:56:47,451 - INFO - topic diff=6.145248, rho=1.000000
# 2024-11-24 18:56:47,712 - INFO - -9.611 per-word bound, 782.1 perplexity estimate based on a held-out corpus of 1612 documents with 44206 words
# 2024-11-24 18:56:47,713 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:47,922 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:47,924 - INFO - topic #1 (0.100): 0.005*"naturalis" + 0.004*"complico" + 0.004*"quiesco" + 0.004*"plenitudo" + 0.003*"wir" + 0.003*"rego" + 0.003*"thesaurus" + 0.003*"contineo" + 0.003*"operatio" + 0.003*"emo"
# 2024-11-24 18:56:47,925 - INFO - topic #5 (0.100): 0.007*"wir" + 0.006*"sponsus" + 0.006*"conuenio" + 0.005*"quaestio" + 0.005*"got" + 0.004*"tango" + 0.004*"seruus" + 0.004*"sponsa" + 0.004*"uater" + 0.004*"aetas"
# 2024-11-24 18:56:47,925 - INFO - topic #9 (0.100): 0.008*"ferrum" + 0.008*"lapis" + 0.006*"aurum" + 0.006*"quies" + 0.005*"pulcher" + 0.004*"leprosus" + 0.004*"color" + 0.004*"sano" + 0.004*"sanctifico" + 0.004*"fons"
# 2024-11-24 18:56:47,926 - INFO - topic #8 (0.100): 0.006*"uitis" + 0.006*"seruus" + 0.004*"trado" + 0.004*"pauper" + 0.004*"aufero" + 0.004*"causa" + 0.003*"indigeo" + 0.003*"labor" + 0.003*"cura" + 0.003*"acquiro"
# 2024-11-24 18:56:47,926 - INFO - topic #2 (0.100): 0.006*"fons" + 0.005*"deficio" + 0.004*"judaeus" + 0.004*"praecedo" + 0.004*"libero" + 0.003*"gaudeo" + 0.003*"crux" + 0.003*"annuntio" + 0.003*"poena" + 0.003*"aduentus"
# 2024-11-24 18:56:47,926 - INFO - topic diff=0.729046, rho=0.707107
# 2024-11-24 18:56:47,927 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.80s', 'datetime': '2024-11-24T18:56:47.927255', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:47,929 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:50,863 - INFO - 1 batches submitted to accumulate stats from 64 documents (1691 virtual)
# 2024-11-24 18:56:50,868 - INFO - 2 batches submitted to accumulate stats from 128 documents (2991 virtual)
# 2024-11-24 18:56:50,870 - INFO - 3 batches submitted to accumulate stats from 192 documents (5136 virtual)
# 2024-11-24 18:56:50,873 - INFO - 4 batches submitted to accumulate stats from 256 documents (6261 virtual)
# 2024-11-24 18:56:50,876 - INFO - 5 batches submitted to accumulate stats from 320 documents (6836 virtual)
# 2024-11-24 18:56:50,878 - INFO - 6 batches submitted to accumulate stats from 384 documents (7536 virtual)
# 2024-11-24 18:56:50,880 - INFO - 7 batches submitted to accumulate stats from 448 documents (8497 virtual)
# 2024-11-24 18:56:50,882 - INFO - 8 batches submitted to accumulate stats from 512 documents (9190 virtual)
# 2024-11-24 18:56:50,886 - INFO - 9 batches submitted to accumulate stats from 576 documents (10163 virtual)
# 2024-11-24 18:56:50,889 - INFO - 10 batches submitted to accumulate stats from 640 documents (11092 virtual)
# 2024-11-24 18:56:50,891 - INFO - 11 batches submitted to accumulate stats from 704 documents (12014 virtual)
# 2024-11-24 18:56:50,893 - INFO - 12 batches submitted to accumulate stats from 768 documents (13307 virtual)
# 2024-11-24 18:56:50,895 - INFO - 13 batches submitted to accumulate stats from 832 documents (15253 virtual)
# 2024-11-24 18:56:50,897 - INFO - 14 batches submitted to accumulate stats from 896 documents (16969 virtual)
# 2024-11-24 18:56:50,898 - INFO - 15 batches submitted to accumulate stats from 960 documents (17191 virtual)
# 2024-11-24 18:56:50,955 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:50,964 - INFO - accumulated word occurrence stats for 17565 virtual documents
# 2024-11-24 18:56:51,098 - INFO - Evaluation metrics - NPMI: 0.2720, Diversity: 0.9100
# 2024-11-24 18:56:51,219 - INFO - Processing fold 2/5
# 2024-11-24 18:56:51,220 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:51,221 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:51,224 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:51,225 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:51,225 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:51,540 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:51,542 - INFO - topic #3 (0.100): 0.007*"pastor" + 0.004*"ostium" + 0.004*"reuelo" + 0.004*"mortalis" + 0.003*"ouis" + 0.003*"medio" + 0.003*"cesso" + 0.003*"figura" + 0.003*"calor" + 0.003*"arbor"
# 2024-11-24 18:56:51,542 - INFO - topic #7 (0.100): 0.005*"pastor" + 0.005*"substantia" + 0.005*"dimitto" + 0.004*"ouis" + 0.004*"arbor" + 0.004*"facies" + 0.004*"persona" + 0.003*"lignum" + 0.003*"produco" + 0.003*"felicitas"
# 2024-11-24 18:56:51,543 - INFO - topic #0 (0.100): 0.008*"trinitas" + 0.006*"consummo" + 0.005*"bonitas" + 0.004*"perdo" + 0.004*"poena" + 0.004*"crux" + 0.004*"lignum" + 0.003*"aduerto" + 0.003*"pateo" + 0.003*"summus"
# 2024-11-24 18:56:51,543 - INFO - topic #9 (0.100): 0.007*"consummo" + 0.005*"aurum" + 0.005*"calor" + 0.004*"manifesto" + 0.004*"fecunditas" + 0.004*"pulcher" + 0.003*"medio" + 0.003*"nexus" + 0.003*"comprehendo" + 0.003*"lapis"
# 2024-11-24 18:56:51,544 - INFO - topic #2 (0.100): 0.004*"crux" + 0.004*"pastor" + 0.004*"passio" + 0.004*"judaeus" + 0.003*"seruio" + 0.003*"animal" + 0.003*"johannus" + 0.003*"eleuo" + 0.003*"substantia" + 0.003*"plenus"
# 2024-11-24 18:56:51,544 - INFO - topic diff=6.115588, rho=1.000000
# 2024-11-24 18:56:51,806 - INFO - -9.632 per-word bound, 793.5 perplexity estimate based on a held-out corpus of 1612 documents with 45002 words
# 2024-11-24 18:56:51,806 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:52,014 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:52,016 - INFO - topic #1 (0.100): 0.007*"magnes" + 0.005*"complico" + 0.005*"aequalitas" + 0.004*"naturalis" + 0.003*"ager" + 0.003*"aurum" + 0.003*"participo" + 0.003*"mensura" + 0.003*"aeternitas" + 0.003*"quiesco"
# 2024-11-24 18:56:52,016 - INFO - topic #5 (0.100): 0.004*"benedico" + 0.004*"got" + 0.004*"sto" + 0.004*"abraham" + 0.004*"praesens" + 0.004*"dignus" + 0.004*"sponsus" + 0.004*"lebens" + 0.003*"populus" + 0.003*"gens"
# 2024-11-24 18:56:52,017 - INFO - topic #9 (0.100): 0.008*"ferrum" + 0.007*"stella" + 0.007*"consummo" + 0.007*"quies" + 0.005*"aurum" + 0.005*"lapis" + 0.004*"pes" + 0.004*"luna" + 0.004*"leprosus" + 0.004*"complementum"
# 2024-11-24 18:56:52,017 - INFO - topic #8 (0.100): 0.005*"exspecto" + 0.004*"timeo" + 0.004*"aufero" + 0.004*"seruus" + 0.003*"trado" + 0.003*"causa" + 0.003*"nolo" + 0.003*"diues" + 0.003*"religio" + 0.003*"mortalis"
# 2024-11-24 18:56:52,018 - INFO - topic #2 (0.100): 0.006*"fons" + 0.005*"deficio" + 0.004*"judaeus" + 0.004*"pastor" + 0.004*"animal" + 0.004*"annuntio" + 0.003*"littera" + 0.003*"ciuitas" + 0.003*"plenus" + 0.003*"subicio"
# 2024-11-24 18:56:52,018 - INFO - topic diff=0.735457, rho=0.707107
# 2024-11-24 18:56:52,019 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.79s', 'datetime': '2024-11-24T18:56:52.019092', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:52,021 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:54,788 - INFO - 1 batches submitted to accumulate stats from 64 documents (1453 virtual)
# 2024-11-24 18:56:54,790 - INFO - 2 batches submitted to accumulate stats from 128 documents (3256 virtual)
# 2024-11-24 18:56:54,792 - INFO - 3 batches submitted to accumulate stats from 192 documents (4979 virtual)
# 2024-11-24 18:56:54,793 - INFO - 4 batches submitted to accumulate stats from 256 documents (6014 virtual)
# 2024-11-24 18:56:54,796 - INFO - 5 batches submitted to accumulate stats from 320 documents (6966 virtual)
# 2024-11-24 18:56:54,797 - INFO - 6 batches submitted to accumulate stats from 384 documents (7619 virtual)
# 2024-11-24 18:56:54,799 - INFO - 7 batches submitted to accumulate stats from 448 documents (8530 virtual)
# 2024-11-24 18:56:54,802 - INFO - 8 batches submitted to accumulate stats from 512 documents (9158 virtual)
# 2024-11-24 18:56:54,804 - INFO - 9 batches submitted to accumulate stats from 576 documents (10323 virtual)
# 2024-11-24 18:56:54,808 - INFO - 10 batches submitted to accumulate stats from 640 documents (11215 virtual)
# 2024-11-24 18:56:54,809 - INFO - 11 batches submitted to accumulate stats from 704 documents (11990 virtual)
# 2024-11-24 18:56:54,811 - INFO - 12 batches submitted to accumulate stats from 768 documents (13162 virtual)
# 2024-11-24 18:56:54,814 - INFO - 13 batches submitted to accumulate stats from 832 documents (14839 virtual)
# 2024-11-24 18:56:54,816 - INFO - 14 batches submitted to accumulate stats from 896 documents (16236 virtual)
# 2024-11-24 18:56:54,816 - INFO - 15 batches submitted to accumulate stats from 960 documents (16369 virtual)
# 2024-11-24 18:56:54,862 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 18:56:54,874 - INFO - accumulated word occurrence stats for 16729 virtual documents
# 2024-11-24 18:56:54,988 - INFO - Evaluation metrics - NPMI: 0.2713, Diversity: 0.9000
# 2024-11-24 18:56:55,128 - INFO - Processing fold 3/5
# 2024-11-24 18:56:55,129 - INFO - using symmetric alpha at 0.1
# 2024-11-24 18:56:55,130 - INFO - using serial LDA version on this node
# 2024-11-24 18:56:55,133 - INFO - running online (single-pass) LDA training, 10 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 18:56:55,134 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 18:56:55,134 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 18:56:55,465 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 18:56:55,467 - INFO - topic #3 (0.100): 0.010*"pastor" + 0.006*"ouis" + 0.004*"medio" + 0.004*"mortalis" + 0.003*"puto" + 0.003*"interior" + 0.003*"arbor" + 0.003*"cesso" + 0.003*"johannus" + 0.003*"reuelo"
# 2024-11-24 18:56:55,468 - INFO - topic #7 (0.100): 0.005*"pastor" + 0.004*"substantia" + 0.004*"uinco" + 0.004*"produco" + 0.004*"persona" + 0.003*"dimitto" + 0.003*"johannus" + 0.003*"ouis" + 0.003*"arbor" + 0.003*"felicitas"
# 2024-11-24 18:56:55,468 - INFO - topic #0 (0.100): 0.008*"trinitas" + 0.005*"bonitas" + 0.004*"perdo" + 0.004*"pateo" + 0.003*"originalis" + 0.003*"summus" + 0.003*"manifesto" + 0.003*"abscondo" + 0.003*"aeternitas" + 0.003*"aduerto"
# 2024-11-24 18:56:55,469 - INFO - topic #9 (0.100): 0.006*"manifesto" + 0.005*"lapis" + 0.005*"consummo" + 0.004*"color" + 0.004*"pulcher" + 0.004*"perhibeo" + 0.003*"calor" + 0.003*"aurum" + 0.003*"medio" + 0.003*"requiro"
# 2024-11-24 18:56:55,469 - INFO - topic #2 (0.100): 0.004*"poena" + 0.004*"crux" + 0.003*"pastor" + 0.003*"seruio" + 0.003*"judaeus" + 0.003*"libero" + 0.003*"tenebrae" + 0.003*"promissio" + 0.003*"animal" + 0.003*"sponsus"
# 2024-11-24 18:56:55,469 - INFO - topic diff=6.093802, rho=1.000000
# 2024-11-24 18:56:55,734 - INFO - -9.623 per-word bound, 788.3 perplexity estimate based on a held-out corpus of 1612 documents with 44813 words
# 2024-11-24 18:56:55,734 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 18:56:55,944 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 18:56:55,946 - INFO - topic #1 (0.100): 0.006*"magnes" + 0.005*"naturalis" + 0.005*"complico" + 0.004*"participo" + 0.004*"operatio" + 0.004*"ferrum" + 0.003*"quiesco" + 0.003*"corporalis" + 0.003*"proximus" + 0.003*"oboedientia"
# 2024-11-24 18:56:55,946 - INFO - topic #5 (0.100): 0.005*"abraham" + 0.005*"sponsus" + 0.004*"quaestio" + 0.004*"octauus" + 0.004*"abraha" + 0.004*"dignus" + 0.004*"benedictio" + 0.003*"gens" + 0.003*"sponsa" + 0.003*"benedico"
# 2024-11-24 18:56:55,947 - INFO - topic #9 (0.100): 0.007*"lapis" + 0.006*"ferrum" + 0.005*"respondeo" + 0.005*"consummo" + 0.005*"color" + 0.005*"manifesto" + 0.005*"aurum" + 0.005*"leprosus" + 0.004*"quies" + 0.004*"multitudo"
# 2024-11-24 18:56:55,947 - INFO - topic #8 (0.100): 0.007*"seruus" + 0.005*"ignoro" + 0.004*"nolo" + 0.004*"exspecto" + 0.004*"trado" + 0.004*"superbia" + 0.004*"causa" + 0.004*"indigeo" + 0.003*"census" + 0.003*"labor"
# 2024-11-24 18:56:55,947 - INFO - topic #2 (0.100): 0.004*"daemonium" + 0.004*"fons" + 0.004*"judaeus" + 0.004*"annuntio" + 0.003*"sponsus" + 0.003*"animal" + 0.003*"colo" + 0.003*"glacies" + 0.003*"gaudeo" + 0.003*"deficio"
# 2024-11-24 18:56:55,948 - INFO - topic diff=0.728246, rho=0.707107
# 2024-11-24 18:56:55,948 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=10, decay=0.5, chunksize=2000> in 0.81s', 'datetime': '2024-11-24T18:56:55.948651', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 18:56:55,951 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 18:56:58,715 - INFO - 1 batches submitted to accumulate stats from 64 documents (1402 virtual)
# 2024-11-24 18:56:58,717 - INFO - 2 batches submitted to accumulate stats from 128 documents (3254 virtual)
# 2024-11-24 18:56:58,719 - INFO - 3 batches submitted to accumulate stats from 192 documents (5226 virtual)
# 2024-11-24 18:56:58,720 - INFO - 4 batches submitted to accumulate stats from 256 documents (5959 virtual)
# 2024-11-24 18:56:58,721 - INFO - 5 batches submitted to accumulate stats from 320 documents (6732 virtual)
# 2024-11-24 18:56:58,724 - INFO - 6 batches submitted to accumulate stats from 384 documents (7525 virtual)
# 2024-11-24 18:56:58,726 - INFO - 7 batches submitted to accumulate stats from 448 documents (8520 virtual)
# 2024-11-24 18:56:58,727 - INFO - 8 batches submitted to accumulate stats from 512 documents (9211 virtual)
# 2024-11-24 18:56:58,729 - INFO - 9 batches submitted to accumulate stats from 576 documents (10264 virtual)
# ...
# 2024-11-24 19:07:34,732 - INFO - -9.248 per-word bound, 607.9 perplexity estimate based on a held-out corpus of 1612 documents with 44813 words
# 2024-11-24 19:07:34,732 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 19:07:35,131 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 19:07:35,134 - INFO - topic #8 (0.500): 0.003*"seruus" + 0.003*"possideo" + 0.003*"diues" + 0.003*"pauper" + 0.002*"nolo" + 0.002*"census" + 0.002*"indigeo" + 0.002*"perdo" + 0.002*"trado" + 0.002*"tango"
# 2024-11-24 19:07:35,135 - INFO - topic #11 (0.500): 0.005*"pes" + 0.003*"habito" + 0.003*"stella" + 0.002*"contemplatio" + 0.002*"pastor" + 0.002*"summus" + 0.002*"ciuitas" + 0.002*"bonitas" + 0.002*"lacrima" + 0.001*"resurgo"
# 2024-11-24 19:07:35,135 - INFO - topic #10 (0.500): 0.016*"wir" + 0.011*"uns" + 0.009*"syn" + 0.009*"got" + 0.008*"alst" + 0.008*"dar" + 0.008*"umb" + 0.007*"no" + 0.007*"unser" + 0.007*"wo"
# 2024-11-24 19:07:35,136 - INFO - topic #14 (0.500): 0.007*"manifesto" + 0.004*"resurrectio" + 0.003*"comprehendo" + 0.003*"corporalis" + 0.002*"esurio" + 0.002*"gusto" + 0.002*"templum" + 0.002*"reuertor" + 0.002*"eicio" + 0.002*"unctio"
# 2024-11-24 19:07:35,136 - INFO - topic #4 (0.500): 0.005*"sanctifico" + 0.003*"corruptibilis" + 0.003*"iustifico" + 0.003*"honor" + 0.003*"offero" + 0.003*"exemplum" + 0.002*"uniuersus" + 0.002*"plenitudo" + 0.002*"daemonium" + 0.002*"exeo"
# 2024-11-24 19:07:35,136 - INFO - topic diff=0.470818, rho=0.707107
# 2024-11-24 19:07:35,138 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=15, decay=0.5, chunksize=2000> in 1.34s', 'datetime': '2024-11-24T19:07:35.138201', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 19:07:35,143 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 19:07:38,814 - INFO - 1 batches submitted to accumulate stats from 64 documents (1402 virtual)
# 2024-11-24 19:07:38,817 - INFO - 2 batches submitted to accumulate stats from 128 documents (3254 virtual)
# 2024-11-24 19:07:38,819 - INFO - 3 batches submitted to accumulate stats from 192 documents (5226 virtual)
# 2024-11-24 19:07:38,822 - INFO - 4 batches submitted to accumulate stats from 256 documents (5959 virtual)
# 2024-11-24 19:07:38,824 - INFO - 5 batches submitted to accumulate stats from 320 documents (6732 virtual)
# 2024-11-24 19:07:38,829 - INFO - 6 batches submitted to accumulate stats from 384 documents (7525 virtual)
# 2024-11-24 19:07:38,832 - INFO - 7 batches submitted to accumulate stats from 448 documents (8520 virtual)
# 2024-11-24 19:07:38,837 - INFO - 8 batches submitted to accumulate stats from 512 documents (9211 virtual)
# 2024-11-24 19:07:38,842 - INFO - 9 batches submitted to accumulate stats from 576 documents (10264 virtual)
# 2024-11-24 19:07:38,845 - INFO - 10 batches submitted to accumulate stats from 640 documents (11160 virtual)
# 2024-11-24 19:07:38,849 - INFO - 11 batches submitted to accumulate stats from 704 documents (12022 virtual)
# 2024-11-24 19:07:38,850 - INFO - 12 batches submitted to accumulate stats from 768 documents (13096 virtual)
# 2024-11-24 19:07:38,852 - INFO - 13 batches submitted to accumulate stats from 832 documents (15159 virtual)
# 2024-11-24 19:07:38,856 - INFO - 14 batches submitted to accumulate stats from 896 documents (16480 virtual)
# 2024-11-24 19:07:38,859 - INFO - 15 batches submitted to accumulate stats from 960 documents (16644 virtual)
# 2024-11-24 19:07:38,959 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 19:07:38,978 - INFO - accumulated word occurrence stats for 16975 virtual documents
# 2024-11-24 19:07:39,234 - INFO - Evaluation metrics - NPMI: 0.0000, Diversity: 0.9200
# 2024-11-24 19:07:39,453 - INFO - Processing fold 4/5
# 2024-11-24 19:07:39,456 - INFO - using serial LDA version on this node
# 2024-11-24 19:07:39,462 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 19:07:39,462 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 19:07:39,463 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 19:07:39,974 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 19:07:39,977 - INFO - topic #13 (0.500): 0.003*"aeternitas" + 0.003*"johannus" + 0.002*"uitis" + 0.002*"calor" + 0.002*"mons" + 0.002*"infirmitas" + 0.002*"arbor" + 0.002*"aurum" + 0.002*"quiesco" + 0.002*"capitulum"
# 2024-11-24 19:07:39,977 - INFO - topic #3 (0.500): 0.003*"pastor" + 0.002*"ostium" + 0.002*"puto" + 0.002*"figura" + 0.002*"reuelo" + 0.002*"interior" + 0.002*"stella" + 0.002*"johannus" + 0.002*"lapis" + 0.002*"medio"
# 2024-11-24 19:07:39,978 - INFO - topic #12 (0.500): 0.002*"facies" + 0.002*"assimilatio" + 0.002*"oboedientia" + 0.002*"seruio" + 0.002*"religio" + 0.002*"passio" + 0.002*"dormio" + 0.002*"summus" + 0.002*"concupiscentia" + 0.002*"necesse"
# 2024-11-24 19:07:39,979 - INFO - topic #6 (0.500): 0.002*"reuelo" + 0.002*"notitia" + 0.002*"saeculum" + 0.002*"plenitudo" + 0.002*"temporalis" + 0.002*"gratus" + 0.002*"paro" + 0.002*"necesse" + 0.002*"purgo" + 0.002*"monachus"
# 2024-11-24 19:07:39,979 - INFO - topic #1 (0.500): 0.004*"omnipotens" + 0.003*"participo" + 0.003*"quiesco" + 0.003*"thesaurus" + 0.003*"emo" + 0.002*"naturalis" + 0.002*"complico" + 0.002*"proximus" + 0.002*"margarita" + 0.002*"longitudo"
# 2024-11-24 19:07:39,979 - INFO - topic diff=1.169007, rho=1.000000
# 2024-11-24 19:07:40,439 - INFO - -9.236 per-word bound, 602.9 perplexity estimate based on a held-out corpus of 1612 documents with 44583 words
# 2024-11-24 19:07:40,440 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 19:07:40,910 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 19:07:40,913 - INFO - topic #8 (0.500): 0.003*"diues" + 0.003*"pauper" + 0.003*"seruus" + 0.003*"labor" + 0.002*"diuitia" + 0.002*"perdo" + 0.002*"cura" + 0.002*"indigeo" + 0.002*"nolo" + 0.002*"auaritia"
# 2024-11-24 19:07:40,914 - INFO - topic #11 (0.500): 0.004*"pes" + 0.003*"quaestio" + 0.003*"habito" + 0.002*"contemplatio" + 0.002*"operatio" + 0.002*"bonitas" + 0.002*"respondeo" + 0.002*"pastor" + 0.002*"medicus" + 0.002*"summus"
# 2024-11-24 19:07:40,914 - INFO - topic #10 (0.500): 0.014*"wir" + 0.009*"uns" + 0.007*"unser" + 0.007*"alst" + 0.006*"umb" + 0.006*"got" + 0.006*"no" + 0.006*"syn" + 0.005*"dar" + 0.004*"wo"
# 2024-11-24 19:07:40,915 - INFO - topic #14 (0.500): 0.005*"manifesto" + 0.003*"resurrectio" + 0.003*"aufero" + 0.003*"primogenitus" + 0.003*"ferrum" + 0.003*"magnes" + 0.002*"perhibeo" + 0.002*"esurio" + 0.002*"unctio" + 0.002*"plenus"
# 2024-11-24 19:07:40,915 - INFO - topic #4 (0.500): 0.004*"uniuersus" + 0.004*"sanctifico" + 0.003*"iustifico" + 0.003*"daemonium" + 0.003*"offero" + 0.003*"corruptibilis" + 0.003*"hostia" + 0.003*"caesar" + 0.003*"plenitudo" + 0.002*"circumcisio"
# 2024-11-24 19:07:40,916 - INFO - topic diff=0.468704, rho=0.707107
# 2024-11-24 19:07:40,917 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=15, decay=0.5, chunksize=2000> in 1.45s', 'datetime': '2024-11-24T19:07:40.917042', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 19:07:40,921 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 19:07:44,487 - INFO - 1 batches submitted to accumulate stats from 64 documents (1683 virtual)
# 2024-11-24 19:07:44,494 - INFO - 2 batches submitted to accumulate stats from 128 documents (3556 virtual)
# 2024-11-24 19:07:44,496 - INFO - 3 batches submitted to accumulate stats from 192 documents (5396 virtual)
# 2024-11-24 19:07:44,499 - INFO - 4 batches submitted to accumulate stats from 256 documents (6529 virtual)
# 2024-11-24 19:07:44,501 - INFO - 5 batches submitted to accumulate stats from 320 documents (7157 virtual)
# 2024-11-24 19:07:44,505 - INFO - 6 batches submitted to accumulate stats from 384 documents (7931 virtual)
# 2024-11-24 19:07:44,507 - INFO - 7 batches submitted to accumulate stats from 448 documents (8801 virtual)
# 2024-11-24 19:07:44,512 - INFO - 8 batches submitted to accumulate stats from 512 documents (9571 virtual)
# 2024-11-24 19:07:44,517 - INFO - 9 batches submitted to accumulate stats from 576 documents (10450 virtual)
# 2024-11-24 19:07:44,519 - INFO - 10 batches submitted to accumulate stats from 640 documents (11337 virtual)
# 2024-11-24 19:07:44,521 - INFO - 11 batches submitted to accumulate stats from 704 documents (11957 virtual)
# 2024-11-24 19:07:44,524 - INFO - 12 batches submitted to accumulate stats from 768 documents (13361 virtual)
# 2024-11-24 19:07:44,526 - INFO - 13 batches submitted to accumulate stats from 832 documents (14854 virtual)
# 2024-11-24 19:07:44,541 - INFO - 14 batches submitted to accumulate stats from 896 documents (17117 virtual)
# 2024-11-24 19:07:44,556 - INFO - 15 batches submitted to accumulate stats from 960 documents (17163 virtual)
# 2024-11-24 19:07:44,675 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 19:07:44,704 - INFO - accumulated word occurrence stats for 17536 virtual documents
# 2024-11-24 19:07:44,951 - INFO - Evaluation metrics - NPMI: 0.2901, Diversity: 0.9000
# 2024-11-24 19:07:45,171 - INFO - Processing fold 5/5
# 2024-11-24 19:07:45,173 - INFO - using serial LDA version on this node
# 2024-11-24 19:07:45,179 - INFO - running online (single-pass) LDA training, 15 topics, 1 passes over the supplied corpus of 3612 documents, updating model once every 2000 documents, evaluating perplexity every 3612 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-11-24 19:07:45,179 - WARNING - too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2024-11-24 19:07:45,180 - INFO - PROGRESS: pass 0, at document #2000/3612
# 2024-11-24 19:07:45,674 - INFO - merging changes from 2000 documents into a model of 3612 documents
# 2024-11-24 19:07:45,677 - INFO - topic #13 (0.500): 0.002*"uitis" + 0.002*"aeternitas" + 0.002*"benedico" + 0.002*"johannus" + 0.002*"sanctifico" + 0.002*"arbor" + 0.002*"calor" + 0.002*"infirmitas" + 0.002*"paradisus" + 0.002*"pateo"
# 2024-11-24 19:07:45,678 - INFO - topic #3 (0.500): 0.003*"pastor" + 0.002*"ostium" + 0.002*"medio" + 0.002*"arbor" + 0.002*"puto" + 0.002*"mortalis" + 0.002*"ouis" + 0.002*"concupiscentia" + 0.002*"figura" + 0.002*"interior"
# 2024-11-24 19:07:45,678 - INFO - topic #12 (0.500): 0.002*"seruio" + 0.002*"oboedientia" + 0.002*"facies" + 0.002*"concupiscentia" + 0.002*"lapis" + 0.002*"religio" + 0.002*"poena" + 0.002*"animal" + 0.002*"diuersus" + 0.002*"offero"
# 2024-11-24 19:07:45,679 - INFO - topic #6 (0.500): 0.003*"reuelo" + 0.002*"consummo" + 0.002*"necesse" + 0.002*"gratus" + 0.002*"resurgo" + 0.002*"notitia" + 0.002*"dimitto" + 0.002*"resurrectio" + 0.002*"plenitudo" + 0.002*"nouus"
# 2024-11-24 19:07:45,679 - INFO - topic #1 (0.500): 0.002*"oboedientia" + 0.002*"plenitudo" + 0.002*"naturalis" + 0.002*"proximus" + 0.002*"quiesco" + 0.002*"rego" + 0.002*"supremus" + 0.002*"substantia" + 0.002*"fidelitas" + 0.002*"dimitto"
# 2024-11-24 19:07:45,680 - INFO - topic diff=1.167956, rho=1.000000
# 2024-11-24 19:07:46,133 - INFO - -9.248 per-word bound, 608.1 perplexity estimate based on a held-out corpus of 1612 documents with 45181 words
# 2024-11-24 19:07:46,133 - INFO - PROGRESS: pass 0, at document #3612/3612
# 2024-11-24 19:07:46,533 - INFO - merging changes from 1612 documents into a model of 3612 documents
# 2024-11-24 19:07:46,536 - INFO - topic #8 (0.500): 0.003*"pauper" + 0.003*"cura" + 0.003*"census" + 0.002*"indigeo" + 0.002*"nolo" + 0.002*"seruus" + 0.002*"diues" + 0.002*"trado" + 0.002*"labor" + 0.002*"auaritia"
# 2024-11-24 19:07:46,537 - INFO - topic #11 (0.500): 0.004*"contemplatio" + 0.004*"pes" + 0.003*"stella" + 0.003*"habito" + 0.003*"relinquo" + 0.003*"quaestio" + 0.002*"operatio" + 0.002*"pastor" + 0.002*"bonitas" + 0.002*"summus"
# 2024-11-24 19:07:46,537 - INFO - topic #10 (0.500): 0.019*"wir" + 0.012*"uns" + 0.009*"alst" + 0.009*"syn" + 0.008*"umb" + 0.008*"unser" + 0.008*"dar" + 0.008*"got" + 0.007*"no" + 0.007*"wo"
# 2024-11-24 19:07:46,538 - INFO - topic #14 (0.500): 0.008*"manifesto" + 0.004*"resurrectio" + 0.003*"perhibeo" + 0.003*"comprehendo" + 0.003*"reuelo" + 0.003*"praedico" + 0.003*"magnes" + 0.003*"primogenitus" + 0.003*"seruus" + 0.002*"ferrum"
# 2024-11-24 19:07:46,538 - INFO - topic #4 (0.500): 0.004*"uniuersus" + 0.004*"sanctifico" + 0.004*"corruptibilis" + 0.003*"offero" + 0.003*"saeculum" + 0.003*"caesar" + 0.003*"unctio" + 0.003*"daemonium" + 0.003*"exemplum" + 0.002*"heres"
# 2024-11-24 19:07:46,539 - INFO - topic diff=0.468524, rho=0.707107
# 2024-11-24 19:07:46,539 - INFO - LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=7048, num_topics=15, decay=0.5, chunksize=2000> in 1.36s', 'datetime': '2024-11-24T19:07:46.539816', 'gensim': '4.3.3', 'python': '3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]', 'platform': 'macOS-15.1-arm64-arm-64bit', 'event': 'created'}
# 2024-11-24 19:07:46,544 - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2024-11-24 19:07:50,195 - INFO - 1 batches submitted to accumulate stats from 64 documents (1579 virtual)
# 2024-11-24 19:07:50,198 - INFO - 2 batches submitted to accumulate stats from 128 documents (3279 virtual)
# 2024-11-24 19:07:50,200 - INFO - 3 batches submitted to accumulate stats from 192 documents (4936 virtual)
# 2024-11-24 19:07:50,202 - INFO - 4 batches submitted to accumulate stats from 256 documents (5833 virtual)
# 2024-11-24 19:07:50,204 - INFO - 5 batches submitted to accumulate stats from 320 documents (6808 virtual)
# 2024-11-24 19:07:50,207 - INFO - 6 batches submitted to accumulate stats from 384 documents (7690 virtual)
# 2024-11-24 19:07:50,211 - INFO - 7 batches submitted to accumulate stats from 448 documents (8552 virtual)
# 2024-11-24 19:07:50,218 - INFO - 8 batches submitted to accumulate stats from 512 documents (9221 virtual)
# 2024-11-24 19:07:50,220 - INFO - 9 batches submitted to accumulate stats from 576 documents (10377 virtual)
# 2024-11-24 19:07:50,223 - INFO - 10 batches submitted to accumulate stats from 640 documents (11026 virtual)
# 2024-11-24 19:07:50,240 - INFO - 11 batches submitted to accumulate stats from 704 documents (11940 virtual)
# 2024-11-24 19:07:50,248 - INFO - 12 batches submitted to accumulate stats from 768 documents (12869 virtual)
# 2024-11-24 19:07:50,252 - INFO - 13 batches submitted to accumulate stats from 832 documents (14715 virtual)
# 2024-11-24 19:07:50,262 - INFO - 14 batches submitted to accumulate stats from 896 documents (16046 virtual)
# 2024-11-24 19:07:50,266 - INFO - 15 batches submitted to accumulate stats from 960 documents (16218 virtual)
# 2024-11-24 19:07:50,359 - INFO - 7 accumulators retrieved from output queue
# 2024-11-24 19:07:50,395 - INFO - accumulated word occurrence stats for 16603 virtual documents
# 2024-11-24 19:07:50,631 - INFO - Evaluation metrics - NPMI: 0.0000, Diversity: 0.9500
# 2024-11-24 19:07:51,890 - INFO -
# Best Model Configuration:
# 2024-11-24 19:07:51,891 - INFO - Experiment ID: 4
# 2024-11-24 19:07:51,892 - INFO - Number of Topics: 10
# 2024-11-24 19:07:51,892 - INFO - Alpha: symmetric
# 2024-11-24 19:07:51,893 - INFO - Eta: 0.5
# 2024-11-24 19:07:51,893 - INFO - Average NPMI: 0.1688
# 2024-11-24 19:07:51,893 - INFO - Average Diversity: 0.9200
# 2024-11-24 19:07:51,894 - INFO - Average Optimal Score: 0.5444
